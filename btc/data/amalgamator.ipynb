# %% [markdown]
# # Amalgamator

# %%
import pandas as pd
from datetime import datetime, timedelta

# %%
coinmetrics = pd.read_parquet('coin-metrics.parquet')
yahoo = pd.read_parquet('yahoo-finance.parquet')

# %%
combined_df = pd.merge(coinmetrics, yahoo, left_index=True, right_index=True, how='outer')

# %%
combined_df.dropna(inplace=True)

# %%
combined_df
# Out:
#             AdrActCnt  AdrBal1in100KCnt  AdrBal1in100MCnt  AdrBal1in10BCnt  \
# 2016-06-16   586017.0            9193.0         1004173.0        3851689.0
# 2016-06-17   575677.0            9173.0         1004144.0        3842029.0
# 2016-06-20   567592.0            9184.0         1006046.0        3847628.0
# 2016-06-21   592134.0            9136.0         1009564.0        3847451.0
# 2016-06-22   553797.0            9139.0         1010570.0        3837593.0
# ...               ...               ...               ...              ...
# 2024-01-30   907924.0            8884.0         3062235.0       20659828.0
# 2024-01-31   870798.0            8893.0         3059619.0       20639287.0
# 2024-02-01   933880.0            8876.0         3060284.0       20636798.0
# 2024-02-02   932903.0            8874.0         3060230.0       20645311.0
# 2024-02-05   852467.0            8867.0         3060156.0       20615216.0
#
# ...

# %%
import pandas as pd

# Assuming combined_df is already defined and contains the columns 'BTC-USD_High' and 'BTC-USD_Low'

# Calculate the percentage difference between 'BTC-USD_High' and 'BTC-USD_Low' for each row
combined_df['Perc_Difference'] = ((combined_df['BTC-USD_High'] - combined_df['BTC-USD_Low']) / combined_df['BTC-USD_Low']) * 100

# Select the last 365 rows and calculate the average percentage difference
average_perc_difference_last_365 = combined_df['Perc_Difference'].tail(365).mean()
med_perc_difference_last_365 = combined_df['Perc_Difference'].tail(365).median()

# Display the average percentage difference
print(f"The average percentage difference between BTC-USD_High and BTC-USD_Low for the last 365 rows is: {average_perc_difference_last_365:.2f}%")
# Display the average percentage difference
print(f"The median percentage difference between BTC-USD_High and BTC-USD_Low for the last 365 rows is: {med_perc_difference_last_365:.2f}%")
# Out:
# The average percentage difference between BTC-USD_High and BTC-USD_Low for the last 365 rows is: 3.83%
# The median percentage difference between BTC-USD_High and BTC-USD_Low for the last 365 rows is: 3.20%

# %%
combined_df.to_parquet('amalgamated.parquet')
