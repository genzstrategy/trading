# %% [markdown]
# # Vernon High

# %%
import pandas as pd

# %%
df = pd.read_parquet("amalgamated.parquet")

# %%
vars = [
    "ETH-CAD_High",
    "ETH-CAD_Low",
    "BTC-CAD_High",
    "BTC-CAD_Low",
    "AdrBalNtv0.01Cnt",
    "AdrBalNtv0.1Cnt",
    "AdrBalNtv1Cnt",
    "AdrBalNtv10Cnt",
    "BlkSizeMeanByte",
    "CapRealUSD",
    "FeeByteMeanNtv",
    "FlowInExNtv",
    "FlowOutExNtv",
    "FlowTfrFromExCnt",
    "GasUsedTxMean",
    "NDF",
    "SplyAct1d",
    "SplyActPct1yr",
    "TxCnt",
    "VelCur1yr",
    'Global_Liquidity_Index'
]


df = df[vars]

# %%
# Assuming df is your DataFrame
#df = df.pct_change()*100

# The first row will be NaN because there's no previous data to subtract from the first entry
# If you wish to remove the NaN values, you can drop the first row
df.dropna(inplace=True)

df
# Out:
#             ETH-CAD_High  ETH-CAD_Low  BTC-CAD_High   BTC-CAD_Low  \
# 2019-04-10    243.850067   233.455215   7222.453125   6922.804688
# 2019-04-11    236.404099   216.744598   7134.264648   6700.027344
# 2019-04-12    221.268066   215.401428   6802.552734   6629.196289
# 2019-04-13    221.835815   217.367996   6836.755859   6749.371094
# 2019-04-14    224.728149   216.914780   6910.552734   6734.143066
# ...                  ...          ...           ...           ...
# 2024-02-01   3148.913574  3042.415771  58550.632812  56831.171875
# 2024-02-02   3088.287109  3013.004883  57877.652344  56241.656250
# 2024-02-03   3107.525391  3067.862793  58432.644531  57157.976562
# 2024-02-04   3136.216309  3090.657471  58429.691406  57797.507812
# 2024-02-05   3111.508301  3059.306396  58076.230469  57048.390625
#
#             AdrBalNtv0.01Cnt  AdrBalNtv0.1Cnt  AdrBalNtv1Cnt  AdrBalNtv10Cnt  \
# 2019-04-10           5852149          2498307         946506          241675
# 2019-04-11           5855391          2500814         945792          241680
# 2019-04-12           5822176          2482677         945504          241730
# 2019-04-13           5812637          2479791         945903          242190
# 2019-04-14           5817917          2483060         947550          242735
# ...                      ...              ...            ...             ...
# 2024-02-01          24720293          5199047        1729337          344532
# 2024-02-02          24732407          5195599        1729374          344511
# 2024-02-03          24733683          5185916        1728662          344395
# 2024-02-04          24723204          5169224        1728661          344281
# 2024-02-05          24713162          5146142        1728854          344070
#
#             BlkSizeMeanByte    CapRealUSD  ...    FlowInExNtv   FlowOutExNtv  \
# 2019-04-10     22604.443842  2.600059e+10  ...  652727.539118  664687.434194
# 2019-04-11     24120.096491  2.591913e+10  ...  665854.926704  732842.668127
# 2019-04-12     20339.050312  2.589640e+10  ...  530283.379688  567581.232267
# 2019-04-13     17601.024371  2.585180e+10  ...  308396.727523  371997.033800
# 2019-04-14     17001.908284  2.588382e+10  ...  354086.636315  404859.573708
# ...                     ...           ...  ...            ...            ...
# 2024-02-01    144260.110285  1.668265e+11  ...  333278.414166  322887.344200
# 2024-02-02    149793.691422  1.667400e+11  ...  224978.990905  335365.852424
# 2024-02-03    153626.986371  1.665798e+11  ...   88094.093613  110625.486725
# 2024-02-04    153334.124877  1.664679e+11  ...  155456.643029  152343.252309
# 2024-02-05    161689.073003  1.664033e+11  ...  230617.498979  369227.537384
#
#             FlowTfrFromExCnt  GasUsedTxMean       NDF     SplyAct1d  \
# 2019-04-10             30935   64542.928792  0.643228  1.128653e+07
# 2019-04-11             32185   61210.885270  0.642956  1.108390e+07
# 2019-04-12             25662   59082.110788  0.642661  1.074513e+07
# 2019-04-13             21413   61141.225004  0.642345  1.006436e+07
# 2019-04-14             20688   68049.051409  0.641738  9.130682e+06
# ...                      ...            ...       ...           ...
# 2024-02-01            103580   95636.857858  0.677078  1.217375e+07
# 2024-02-02            103742   97339.905076  0.677616  1.248846e+07
# 2024-02-03             93780  102296.542796  0.677607  1.176235e+07
# 2024-02-04             89438  102710.415043  0.678024  9.964788e+06
# 2024-02-05             95967   96329.680096  0.677587  1.135770e+07
#
#             SplyActPct1yr    TxCnt  VelCur1yr  Global_Liquidity_Index
# 2019-04-10      68.702818   674070   8.253820            15763.904344
# 2019-04-11      68.670073   729032   8.266696            15429.280313
# 2019-04-12      68.670112   694793   8.268599            15012.490510
# 2019-04-13      68.672716   614291   8.259578            14025.330765
# 2019-04-14      68.626068   551055   8.266103            14086.338730
# ...                   ...      ...        ...                     ...
# 2024-02-01      36.087370  1127338   6.056708           123571.494066
# 2024-02-02      35.971409  1108172   6.045875           122242.497035
# 2024-02-03      35.937981  1054604   6.036129           121766.009277
# 2024-02-04      35.919804  1049649   6.033078           122454.072998
# 2024-02-05      35.852078  1120237   6.044788           123316.901832
#
# [1763 rows x 21 columns]

# %% [raw]
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# # Assuming df is your DataFrame and 'ETH-CAD_High' is the column of interest
#
# # Histogram
# plt.figure(figsize=(10, 6))
# plt.hist(df['ETH-CAD_High'], bins=30, edgecolor='black')
# plt.title('Distribution of ETH-CAD High Values - Histogram')
# plt.xlabel('ETH-CAD High')
# plt.ylabel('Frequency')
# plt.show()
#
# # KDE Plot
# plt.figure(figsize=(10, 6))
# sns.kdeplot(df['ETH-CAD_High'], fill=True)
# plt.title('Distribution of ETH-CAD High Values - KDE Plot')
# plt.xlabel('ETH-CAD High')
# plt.ylabel('Density')
# plt.show()

# %%
import pandas as pd
import numpy as np
import torch

from gluonts.dataset.common import ListDataset
from gluonts.torch.model.tft import TemporalFusionTransformerEstimator
from gluonts.transform.feature import MissingValueImputation

torch.set_float32_matmul_precision('medium')
                                   
# Assuming df is your DataFrame with the data
target_column = 'ETH-CAD_High'  # Replace with your target column name

# Ensure the DataFrame's index is a datetime index and set the frequency explicitly if needed
df.index = pd.to_datetime(df.index)
freq = "D"  # Set the frequency of your data, e.g., 'D' for daily. Adjust as needed.
df = df.asfreq(freq)

# Define the prediction length
prediction_length = 1  # Set your prediction length

# Select dynamic features from the DataFrame, excluding the target column
past_dynamic_feature_columns = df.columns.drop(target_column)  # This excludes the target column

# Extract dynamic features as a numpy array
past_dynamic_features = df[past_dynamic_feature_columns].values.transpose()

# Assuming all dynamic features are known in the future, adjust the dimensions accordingly
past_dynamic_dims  = [1] * len(past_dynamic_feature_columns)  # Adjust based on actual dynamic features

# Make sure the lengths match when creating ListDataset
training_data = ListDataset([
    {
        "start": df.index[0],
        "target": df[target_column][:-prediction_length],
        "past_feat_dynamic_real": past_dynamic_features[:, :-prediction_length]
    }
], freq=freq)

# Adjust the slicing for dynamic features for the test dataset to ensure correct dimensions
test_past_dynamic_features_sliced = past_dynamic_features[:, -prediction_length:]

test_data = ListDataset([
    {
        "start": df.index[-prediction_length],
        "target": df[target_column][-prediction_length:].values,
        "past_feat_dynamic_real": test_past_dynamic_features_sliced
    }
], freq=freq)

# Initialize the Temporal Fusion Transformer Estimator
estimator = TemporalFusionTransformerEstimator(
    freq=freq,
    prediction_length=prediction_length,
    context_length=7,  # Optional: adjust based on your needs
    num_heads=32,
    hidden_dim=1024,
    variable_dim=1024,
    past_dynamic_dims= past_dynamic_dims,
    quantiles=[0.1, 0.5, 0.9],  # Specifying the quantiles for forecasting
    lr=0.001,
    weight_decay=1e-08,
    dropout_rate=0.1,
    patience=10,
    batch_size=128,
    num_batches_per_epoch=100,
    trainer_kwargs={'max_epochs': 500},  # Adjust 'gpus' based on your setup
)

# Train the model
predictor = estimator.train(training_data)

# Debugging: Print dimensions to verify alignment
print(f"Past Dynamic Features Training Shape: {past_dynamic_features[:, :-prediction_length].shape}")
print(f"Past Dynamic Features Test Shape: {test_past_dynamic_features_sliced.shape}")

# Collect actual and predicted values for evaluation, including percentiles
actuals = df[target_column][-prediction_length:].values
mean_predictions = []
p10_predictions = []
p50_predictions = []
p90_predictions = []

for forecast in predictor.predict(test_data):
    mean_predictions.append(forecast.mean)
    p10_predictions.append(forecast.quantile(0.1))
    p50_predictions.append(forecast.quantile(0.5))  # Median
    p90_predictions.append(forecast.quantile(0.9))

# Convert lists to numpy arrays for slicing
mean_predictions = np.array(mean_predictions).flatten()[:prediction_length]
p10_predictions = np.array(p10_predictions).flatten()[:prediction_length]
p50_predictions = np.array(p50_predictions).flatten()[:prediction_length]
p90_predictions = np.array(p90_predictions).flatten()[:prediction_length]
# Out:
# Trainer will use only 1 of 2 GPUs because it is running inside an interactive / notebook environment. You may try to set `Trainer(devices=2)` but please note that multi-GPU inside interactive / notebook environments is considered experimental and unstable. Your mileage may vary.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# C:\Users\Windows\AppData\Local\Programs\Python\Python311\Lib\site-packages\lightning\pytorch\trainer\configuration_validator.py:74: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name  | Type                           | Params | In sizes                                                                      | Out sizes
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# 0 | model | TemporalFusionTransformerModel | 211 M  | [[1, 7], [1, 7], [1, 1], [1, 1], [1, 8, 3], [1, 8, 0], [1, 7, 20], [1, 7, 0]] | [1, 3, 1]
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# 211 M     Trainable params
# 0         Non-trainable params
# 211 M     Total params
# 846.943   Total estimated model params size (MB)
# Training: |                                                                                      | 0/? [00:00<…
# Epoch 0, global step 100: 'train_loss' reached 203.53326 (best 203.53326), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=0-step=100.ckpt' as top 1
# Epoch 1, global step 200: 'train_loss' reached 107.11464 (best 107.11464), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=1-step=200.ckpt' as top 1
# Epoch 2, global step 300: 'train_loss' reached 102.12417 (best 102.12417), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=2-step=300.ckpt' as top 1
# Epoch 3, global step 400: 'train_loss' reached 99.29439 (best 99.29439), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=3-step=400.ckpt' as top 1
# Epoch 4, global step 500: 'train_loss' reached 96.84353 (best 96.84353), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=4-step=500.ckpt' as top 1
# Epoch 5, global step 600: 'train_loss' reached 87.64778 (best 87.64778), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=5-step=600.ckpt' as top 1
# Epoch 6, global step 700: 'train_loss' reached 77.72391 (best 77.72391), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=6-step=700.ckpt' as top 1
# Epoch 7, global step 800: 'train_loss' reached 68.49969 (best 68.49969), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=7-step=800.ckpt' as top 1
# Epoch 8, global step 900: 'train_loss' reached 59.25204 (best 59.25204), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=8-step=900.ckpt' as top 1
# Epoch 9, global step 1000: 'train_loss' was not in top 1
# Epoch 10, global step 1100: 'train_loss' reached 50.55329 (best 50.55329), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=10-step=1100.ckpt' as top 1
# Epoch 11, global step 1200: 'train_loss' reached 39.65656 (best 39.65656), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=11-step=1200.ckpt' as top 1
# Epoch 12, global step 1300: 'train_loss' reached 36.06071 (best 36.06071), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=12-step=1300.ckpt' as top 1
# Epoch 13, global step 1400: 'train_loss' reached 35.44884 (best 35.44884), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=13-step=1400.ckpt' as top 1
# Epoch 14, global step 1500: 'train_loss' reached 28.76963 (best 28.76963), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=14-step=1500.ckpt' as top 1
# Epoch 15, global step 1600: 'train_loss' reached 24.87180 (best 24.87180), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=15-step=1600.ckpt' as top 1
# Epoch 16, global step 1700: 'train_loss' reached 21.87431 (best 21.87431), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=16-step=1700.ckpt' as top 1
# Epoch 17, global step 1800: 'train_loss' reached 20.88580 (best 20.88580), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=17-step=1800.ckpt' as top 1
# Epoch 18, global step 1900: 'train_loss' reached 19.97724 (best 19.97724), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=18-step=1900.ckpt' as top 1
# Epoch 19, global step 2000: 'train_loss' reached 15.73649 (best 15.73649), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=19-step=2000.ckpt' as top 1
# Epoch 20, global step 2100: 'train_loss' reached 14.51631 (best 14.51631), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=20-step=2100.ckpt' as top 1
# Epoch 21, global step 2200: 'train_loss' was not in top 1
# Epoch 22, global step 2300: 'train_loss' was not in top 1
# Epoch 23, global step 2400: 'train_loss' reached 14.48188 (best 14.48188), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=23-step=2400.ckpt' as top 1
# Epoch 24, global step 2500: 'train_loss' reached 13.21590 (best 13.21590), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=24-step=2500.ckpt' as top 1
# Epoch 25, global step 2600: 'train_loss' reached 11.16833 (best 11.16833), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=25-step=2600.ckpt' as top 1
# Epoch 26, global step 2700: 'train_loss' was not in top 1
# Epoch 27, global step 2800: 'train_loss' was not in top 1
# Epoch 28, global step 2900: 'train_loss' was not in top 1
# Epoch 29, global step 3000: 'train_loss' was not in top 1
# Epoch 30, global step 3100: 'train_loss' was not in top 1
# Epoch 31, global step 3200: 'train_loss' was not in top 1
# Epoch 32, global step 3300: 'train_loss' reached 10.44602 (best 10.44602), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=32-step=3300.ckpt' as top 1
# Epoch 33, global step 3400: 'train_loss' reached 9.49660 (best 9.49660), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=33-step=3400.ckpt' as top 1
# Epoch 34, global step 3500: 'train_loss' was not in top 1
# Epoch 35, global step 3600: 'train_loss' reached 8.60426 (best 8.60426), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=35-step=3600.ckpt' as top 1
# Epoch 36, global step 3700: 'train_loss' was not in top 1
# Epoch 37, global step 3800: 'train_loss' was not in top 1
# Epoch 38, global step 3900: 'train_loss' reached 7.37752 (best 7.37752), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=38-step=3900.ckpt' as top 1
# Epoch 39, global step 4000: 'train_loss' was not in top 1
# Epoch 40, global step 4100: 'train_loss' reached 6.51784 (best 6.51784), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=40-step=4100.ckpt' as top 1
# Epoch 41, global step 4200: 'train_loss' was not in top 1
# Epoch 42, global step 4300: 'train_loss' was not in top 1
# Epoch 43, global step 4400: 'train_loss' was not in top 1
# Epoch 44, global step 4500: 'train_loss' was not in top 1
# Epoch 45, global step 4600: 'train_loss' was not in top 1
# Epoch 46, global step 4700: 'train_loss' was not in top 1
# Epoch 47, global step 4800: 'train_loss' was not in top 1
# Epoch 48, global step 4900: 'train_loss' was not in top 1
# Epoch 49, global step 5000: 'train_loss' was not in top 1
# Epoch 50, global step 5100: 'train_loss' was not in top 1
# Epoch 51, global step 5200: 'train_loss' reached 6.27494 (best 6.27494), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=51-step=5200.ckpt' as top 1
# Epoch 52, global step 5300: 'train_loss' reached 4.78315 (best 4.78315), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=52-step=5300.ckpt' as top 1
# Epoch 53, global step 5400: 'train_loss' was not in top 1
# Epoch 54, global step 5500: 'train_loss' was not in top 1
# Epoch 55, global step 5600: 'train_loss' reached 4.74764 (best 4.74764), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=55-step=5600.ckpt' as top 1
# Epoch 56, global step 5700: 'train_loss' reached 4.39262 (best 4.39262), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=56-step=5700.ckpt' as top 1
# Epoch 57, global step 5800: 'train_loss' reached 4.06452 (best 4.06452), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=57-step=5800.ckpt' as top 1
# Epoch 58, global step 5900: 'train_loss' was not in top 1
# Epoch 59, global step 6000: 'train_loss' was not in top 1
# Epoch 60, global step 6100: 'train_loss' was not in top 1
# Epoch 61, global step 6200: 'train_loss' reached 3.73129 (best 3.73129), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=61-step=6200.ckpt' as top 1
# Epoch 62, global step 6300: 'train_loss' reached 3.55209 (best 3.55209), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=62-step=6300.ckpt' as top 1
# Epoch 63, global step 6400: 'train_loss' was not in top 1
# Epoch 64, global step 6500: 'train_loss' was not in top 1
# Epoch 65, global step 6600: 'train_loss' was not in top 1
# Epoch 66, global step 6700: 'train_loss' was not in top 1
# Epoch 67, global step 6800: 'train_loss' was not in top 1
# Epoch 68, global step 6900: 'train_loss' was not in top 1
# Epoch 69, global step 7000: 'train_loss' was not in top 1
# Epoch 70, global step 7100: 'train_loss' was not in top 1
# Epoch 71, global step 7200: 'train_loss' reached 3.23671 (best 3.23671), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=71-step=7200.ckpt' as top 1
# Epoch 72, global step 7300: 'train_loss' reached 3.03720 (best 3.03720), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=72-step=7300.ckpt' as top 1
# Epoch 73, global step 7400: 'train_loss' reached 2.86901 (best 2.86901), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=73-step=7400.ckpt' as top 1
# Epoch 74, global step 7500: 'train_loss' was not in top 1
# Epoch 75, global step 7600: 'train_loss' was not in top 1
# Epoch 76, global step 7700: 'train_loss' was not in top 1
# Epoch 77, global step 7800: 'train_loss' was not in top 1
# Epoch 78, global step 7900: 'train_loss' was not in top 1
# Epoch 79, global step 8000: 'train_loss' was not in top 1
# Epoch 80, global step 8100: 'train_loss' reached 2.82228 (best 2.82228), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=80-step=8100.ckpt' as top 1
# Epoch 81, global step 8200: 'train_loss' reached 2.41010 (best 2.41010), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=81-step=8200.ckpt' as top 1
# Epoch 82, global step 8300: 'train_loss' reached 2.25586 (best 2.25586), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=82-step=8300.ckpt' as top 1
# Epoch 83, global step 8400: 'train_loss' was not in top 1
# Epoch 84, global step 8500: 'train_loss' was not in top 1
# Epoch 85, global step 8600: 'train_loss' was not in top 1
# Epoch 86, global step 8700: 'train_loss' was not in top 1
# Epoch 87, global step 8800: 'train_loss' was not in top 1
# Epoch 88, global step 8900: 'train_loss' was not in top 1
# Epoch 89, global step 9000: 'train_loss' was not in top 1
# Epoch 90, global step 9100: 'train_loss' reached 2.18884 (best 2.18884), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=90-step=9100.ckpt' as top 1
# Epoch 91, global step 9200: 'train_loss' was not in top 1
# Epoch 92, global step 9300: 'train_loss' was not in top 1
# Epoch 93, global step 9400: 'train_loss' reached 2.16734 (best 2.16734), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=93-step=9400.ckpt' as top 1
# Epoch 94, global step 9500: 'train_loss' was not in top 1
# Epoch 95, global step 9600: 'train_loss' was not in top 1
# Epoch 96, global step 9700: 'train_loss' was not in top 1
# Epoch 97, global step 9800: 'train_loss' was not in top 1
# Epoch 98, global step 9900: 'train_loss' was not in top 1
# Epoch 99, global step 10000: 'train_loss' was not in top 1
# Epoch 100, global step 10100: 'train_loss' was not in top 1
# Epoch 101, global step 10200: 'train_loss' was not in top 1
# Epoch 102, global step 10300: 'train_loss' reached 2.16212 (best 2.16212), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=102-step=10300.ckpt' as top 1
# Epoch 103, global step 10400: 'train_loss' was not in top 1
# Epoch 104, global step 10500: 'train_loss' was not in top 1
# Epoch 105, global step 10600: 'train_loss' reached 1.99987 (best 1.99987), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=105-step=10600.ckpt' as top 1
# Epoch 106, global step 10700: 'train_loss' was not in top 1
# Epoch 107, global step 10800: 'train_loss' reached 1.83142 (best 1.83142), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=107-step=10800.ckpt' as top 1
# Epoch 108, global step 10900: 'train_loss' reached 1.71007 (best 1.71007), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=108-step=10900.ckpt' as top 1
# Epoch 109, global step 11000: 'train_loss' was not in top 1
# Epoch 110, global step 11100: 'train_loss' was not in top 1
# Epoch 111, global step 11200: 'train_loss' was not in top 1
# Epoch 112, global step 11300: 'train_loss' was not in top 1
# Epoch 113, global step 11400: 'train_loss' was not in top 1
# Epoch 114, global step 11500: 'train_loss' reached 1.69216 (best 1.69216), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=114-step=11500.ckpt' as top 1
# Epoch 115, global step 11600: 'train_loss' was not in top 1
# Epoch 116, global step 11700: 'train_loss' was not in top 1
# Epoch 117, global step 11800: 'train_loss' was not in top 1
# Epoch 118, global step 11900: 'train_loss' was not in top 1
# Epoch 119, global step 12000: 'train_loss' was not in top 1
# Epoch 120, global step 12100: 'train_loss' reached 1.64320 (best 1.64320), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=120-step=12100.ckpt' as top 1
# Epoch 121, global step 12200: 'train_loss' reached 1.63251 (best 1.63251), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=121-step=12200.ckpt' as top 1
# Epoch 122, global step 12300: 'train_loss' was not in top 1
# Epoch 123, global step 12400: 'train_loss' was not in top 1
# Epoch 124, global step 12500: 'train_loss' was not in top 1
# Epoch 125, global step 12600: 'train_loss' was not in top 1
# Epoch 126, global step 12700: 'train_loss' was not in top 1
# Epoch 127, global step 12800: 'train_loss' was not in top 1
# Epoch 128, global step 12900: 'train_loss' was not in top 1
# Epoch 129, global step 13000: 'train_loss' was not in top 1
# Epoch 130, global step 13100: 'train_loss' was not in top 1
# Epoch 131, global step 13200: 'train_loss' was not in top 1
# Epoch 132, global step 13300: 'train_loss' was not in top 1
# Epoch 133, global step 13400: 'train_loss' was not in top 1
# Epoch 134, global step 13500: 'train_loss' reached 1.15374 (best 1.15374), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=134-step=13500.ckpt' as top 1
# Epoch 135, global step 13600: 'train_loss' was not in top 1
# Epoch 136, global step 13700: 'train_loss' was not in top 1
# Epoch 137, global step 13800: 'train_loss' was not in top 1
# Epoch 138, global step 13900: 'train_loss' reached 1.10556 (best 1.10556), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=138-step=13900.ckpt' as top 1
# Epoch 139, global step 14000: 'train_loss' was not in top 1
# Epoch 140, global step 14100: 'train_loss' was not in top 1
# Epoch 141, global step 14200: 'train_loss' was not in top 1
# Epoch 142, global step 14300: 'train_loss' was not in top 1
# Epoch 143, global step 14400: 'train_loss' reached 1.07777 (best 1.07777), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=143-step=14400.ckpt' as top 1
# Epoch 144, global step 14500: 'train_loss' reached 1.02088 (best 1.02088), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=144-step=14500.ckpt' as top 1
# Epoch 145, global step 14600: 'train_loss' was not in top 1
# Epoch 146, global step 14700: 'train_loss' was not in top 1
# Epoch 147, global step 14800: 'train_loss' reached 0.96794 (best 0.96794), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=147-step=14800.ckpt' as top 1
# Epoch 148, global step 14900: 'train_loss' was not in top 1
# Epoch 149, global step 15000: 'train_loss' was not in top 1
# Epoch 150, global step 15100: 'train_loss' was not in top 1
# Epoch 151, global step 15200: 'train_loss' was not in top 1
# Epoch 152, global step 15300: 'train_loss' was not in top 1
# Epoch 153, global step 15400: 'train_loss' was not in top 1
# Epoch 154, global step 15500: 'train_loss' was not in top 1
# Epoch 155, global step 15600: 'train_loss' was not in top 1
# Epoch 156, global step 15700: 'train_loss' was not in top 1
# Epoch 157, global step 15800: 'train_loss' was not in top 1
# Epoch 158, global step 15900: 'train_loss' reached 0.93197 (best 0.93197), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=158-step=15900.ckpt' as top 1
# Epoch 159, global step 16000: 'train_loss' was not in top 1
# Epoch 160, global step 16100: 'train_loss' was not in top 1
# Epoch 161, global step 16200: 'train_loss' was not in top 1
# Epoch 162, global step 16300: 'train_loss' was not in top 1
# Epoch 163, global step 16400: 'train_loss' was not in top 1
# Epoch 164, global step 16500: 'train_loss' was not in top 1
# Epoch 165, global step 16600: 'train_loss' was not in top 1
# Epoch 166, global step 16700: 'train_loss' was not in top 1
# Epoch 167, global step 16800: 'train_loss' was not in top 1
# Epoch 168, global step 16900: 'train_loss' was not in top 1
# Epoch 169, global step 17000: 'train_loss' was not in top 1
# Epoch 170, global step 17100: 'train_loss' reached 0.90780 (best 0.90780), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=170-step=17100.ckpt' as top 1
# Epoch 171, global step 17200: 'train_loss' reached 0.84597 (best 0.84597), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=171-step=17200.ckpt' as top 1
# Epoch 172, global step 17300: 'train_loss' reached 0.79546 (best 0.79546), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=172-step=17300.ckpt' as top 1
# Epoch 173, global step 17400: 'train_loss' reached 0.73653 (best 0.73653), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=173-step=17400.ckpt' as top 1
# Epoch 174, global step 17500: 'train_loss' reached 0.72901 (best 0.72901), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=174-step=17500.ckpt' as top 1
# Epoch 175, global step 17600: 'train_loss' reached 0.56342 (best 0.56342), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=175-step=17600.ckpt' as top 1
# Epoch 176, global step 17700: 'train_loss' was not in top 1
# Epoch 177, global step 17800: 'train_loss' was not in top 1
# Epoch 178, global step 17900: 'train_loss' was not in top 1
# Epoch 179, global step 18000: 'train_loss' was not in top 1
# Epoch 180, global step 18100: 'train_loss' was not in top 1
# Epoch 181, global step 18200: 'train_loss' was not in top 1
# Epoch 182, global step 18300: 'train_loss' was not in top 1
# Epoch 183, global step 18400: 'train_loss' was not in top 1
# Epoch 184, global step 18500: 'train_loss' was not in top 1
# Epoch 185, global step 18600: 'train_loss' was not in top 1
# Epoch 186, global step 18700: 'train_loss' was not in top 1
# Epoch 187, global step 18800: 'train_loss' reached 0.43113 (best 0.43113), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=187-step=18800.ckpt' as top 1
# Epoch 188, global step 18900: 'train_loss' was not in top 1
# Epoch 189, global step 19000: 'train_loss' was not in top 1
# Epoch 190, global step 19100: 'train_loss' was not in top 1
# Epoch 191, global step 19200: 'train_loss' was not in top 1
# Epoch 192, global step 19300: 'train_loss' was not in top 1
# Epoch 193, global step 19400: 'train_loss' was not in top 1
# Epoch 194, global step 19500: 'train_loss' was not in top 1
# Epoch 195, global step 19600: 'train_loss' was not in top 1
# Epoch 196, global step 19700: 'train_loss' was not in top 1
# Epoch 197, global step 19800: 'train_loss' was not in top 1
# Epoch 198, global step 19900: 'train_loss' was not in top 1
# Epoch 199, global step 20000: 'train_loss' reached 0.29053 (best 0.29053), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=199-step=20000.ckpt' as top 1
# Epoch 200, global step 20100: 'train_loss' was not in top 1
# Epoch 201, global step 20200: 'train_loss' was not in top 1
# Epoch 202, global step 20300: 'train_loss' was not in top 1
# Epoch 203, global step 20400: 'train_loss' was not in top 1
# Epoch 204, global step 20500: 'train_loss' was not in top 1
# Epoch 205, global step 20600: 'train_loss' was not in top 1
# Epoch 206, global step 20700: 'train_loss' was not in top 1
# Epoch 207, global step 20800: 'train_loss' was not in top 1
# Epoch 208, global step 20900: 'train_loss' was not in top 1
# Epoch 209, global step 21000: 'train_loss' was not in top 1
# Epoch 210, global step 21100: 'train_loss' was not in top 1
# Epoch 211, global step 21200: 'train_loss' was not in top 1
# Epoch 212, global step 21300: 'train_loss' was not in top 1
# Epoch 213, global step 21400: 'train_loss' was not in top 1
# Epoch 214, global step 21500: 'train_loss' was not in top 1
# Epoch 215, global step 21600: 'train_loss' was not in top 1
# Epoch 216, global step 21700: 'train_loss' was not in top 1
# Epoch 217, global step 21800: 'train_loss' was not in top 1
# Epoch 218, global step 21900: 'train_loss' was not in top 1
# Epoch 219, global step 22000: 'train_loss' was not in top 1
# Epoch 220, global step 22100: 'train_loss' was not in top 1
# Epoch 221, global step 22200: 'train_loss' was not in top 1
# Epoch 222, global step 22300: 'train_loss' was not in top 1
# Epoch 223, global step 22400: 'train_loss' was not in top 1
# Epoch 224, global step 22500: 'train_loss' was not in top 1
# Epoch 225, global step 22600: 'train_loss' was not in top 1
# Epoch 226, global step 22700: 'train_loss' was not in top 1
# Epoch 227, global step 22800: 'train_loss' was not in top 1
# Epoch 228, global step 22900: 'train_loss' was not in top 1
# Epoch 229, global step 23000: 'train_loss' was not in top 1
# Epoch 230, global step 23100: 'train_loss' was not in top 1
# Epoch 231, global step 23200: 'train_loss' was not in top 1
# Epoch 232, global step 23300: 'train_loss' reached 0.26606 (best 0.26606), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=232-step=23300.ckpt' as top 1
# Epoch 233, global step 23400: 'train_loss' was not in top 1
# Epoch 234, global step 23500: 'train_loss' was not in top 1
# Epoch 235, global step 23600: 'train_loss' was not in top 1
# Epoch 236, global step 23700: 'train_loss' was not in top 1
# Epoch 237, global step 23800: 'train_loss' was not in top 1
# Epoch 238, global step 23900: 'train_loss' was not in top 1
# Epoch 239, global step 24000: 'train_loss' was not in top 1
# Epoch 240, global step 24100: 'train_loss' was not in top 1
# Epoch 241, global step 24200: 'train_loss' was not in top 1
# Epoch 242, global step 24300: 'train_loss' was not in top 1
# Epoch 243, global step 24400: 'train_loss' was not in top 1
# Epoch 244, global step 24500: 'train_loss' was not in top 1
# Epoch 245, global step 24600: 'train_loss' was not in top 1
# Epoch 246, global step 24700: 'train_loss' was not in top 1
# Epoch 247, global step 24800: 'train_loss' was not in top 1
# Epoch 248, global step 24900: 'train_loss' was not in top 1
# Epoch 249, global step 25000: 'train_loss' was not in top 1
# Epoch 250, global step 25100: 'train_loss' was not in top 1
# Epoch 251, global step 25200: 'train_loss' was not in top 1
# Epoch 252, global step 25300: 'train_loss' was not in top 1
# Epoch 253, global step 25400: 'train_loss' was not in top 1
# Epoch 254, global step 25500: 'train_loss' was not in top 1
# Epoch 255, global step 25600: 'train_loss' was not in top 1
# Epoch 256, global step 25700: 'train_loss' was not in top 1
# Epoch 257, global step 25800: 'train_loss' was not in top 1
# Epoch 258, global step 25900: 'train_loss' was not in top 1
# Epoch 259, global step 26000: 'train_loss' was not in top 1
# Epoch 260, global step 26100: 'train_loss' was not in top 1
# Epoch 261, global step 26200: 'train_loss' was not in top 1
# Epoch 262, global step 26300: 'train_loss' was not in top 1
# Epoch 263, global step 26400: 'train_loss' was not in top 1
# Epoch 264, global step 26500: 'train_loss' was not in top 1
# Epoch 265, global step 26600: 'train_loss' was not in top 1
# Epoch 266, global step 26700: 'train_loss' was not in top 1
# Epoch 267, global step 26800: 'train_loss' was not in top 1
# Epoch 268, global step 26900: 'train_loss' was not in top 1
# Epoch 269, global step 27000: 'train_loss' was not in top 1
# Epoch 270, global step 27100: 'train_loss' was not in top 1
# Epoch 271, global step 27200: 'train_loss' was not in top 1
# Epoch 272, global step 27300: 'train_loss' was not in top 1
# Epoch 273, global step 27400: 'train_loss' was not in top 1
# Epoch 274, global step 27500: 'train_loss' was not in top 1
# Epoch 275, global step 27600: 'train_loss' was not in top 1
# Epoch 276, global step 27700: 'train_loss' was not in top 1
# Epoch 277, global step 27800: 'train_loss' was not in top 1
# Epoch 278, global step 27900: 'train_loss' was not in top 1
# Epoch 279, global step 28000: 'train_loss' was not in top 1
# Epoch 280, global step 28100: 'train_loss' was not in top 1
# Epoch 281, global step 28200: 'train_loss' was not in top 1
# Epoch 282, global step 28300: 'train_loss' was not in top 1
# Epoch 283, global step 28400: 'train_loss' was not in top 1
# Epoch 284, global step 28500: 'train_loss' was not in top 1
# Epoch 285, global step 28600: 'train_loss' was not in top 1
# Epoch 286, global step 28700: 'train_loss' was not in top 1
# Epoch 287, global step 28800: 'train_loss' reached 0.06818 (best 0.06818), saving model to 'C:\\Users\\Windows\\Desktop\\GZS\\trading\\eth\\vernon\\lightning_logs\\version_4\\checkpoints\\epoch=287-step=28800.ckpt' as top 1
# Epoch 288, global step 28900: 'train_loss' was not in top 1
# Epoch 289, global step 29000: 'train_loss' was not in top 1
# Epoch 290, global step 29100: 'train_loss' was not in top 1
# Epoch 291, global step 29200: 'train_loss' was not in top 1
# Epoch 292, global step 29300: 'train_loss' was not in top 1
# Epoch 293, global step 29400: 'train_loss' was not in top 1
# Epoch 294, global step 29500: 'train_loss' was not in top 1
# Epoch 295, global step 29600: 'train_loss' was not in top 1
# Epoch 296, global step 29700: 'train_loss' was not in top 1
# Epoch 297, global step 29800: 'train_loss' was not in top 1
# Epoch 298, global step 29900: 'train_loss' was not in top 1
# Epoch 299, global step 30000: 'train_loss' was not in top 1
# Epoch 300, global step 30100: 'train_loss' was not in top 1
# Epoch 301, global step 30200: 'train_loss' was not in top 1
# Epoch 302, global step 30300: 'train_loss' was not in top 1
# Epoch 303, global step 30400: 'train_loss' was not in top 1
# Epoch 304, global step 30500: 'train_loss' was not in top 1
# Epoch 305, global step 30600: 'train_loss' was not in top 1
# Epoch 306, global step 30700: 'train_loss' was not in top 1
# Epoch 307, global step 30800: 'train_loss' was not in top 1
# Epoch 308, global step 30900: 'train_loss' was not in top 1
# Epoch 309, global step 31000: 'train_loss' was not in top 1
# Epoch 310, global step 31100: 'train_loss' was not in top 1
# Epoch 311, global step 31200: 'train_loss' was not in top 1
# Epoch 312, global step 31300: 'train_loss' was not in top 1
# Epoch 313, global step 31400: 'train_loss' was not in top 1
# Epoch 314, global step 31500: 'train_loss' was not in top 1
# Epoch 315, global step 31600: 'train_loss' was not in top 1
# Epoch 316, global step 31700: 'train_loss' was not in top 1
# Epoch 317, global step 31800: 'train_loss' was not in top 1
# Epoch 318, global step 31900: 'train_loss' was not in top 1
# Epoch 319, global step 32000: 'train_loss' was not in top 1
# Epoch 320, global step 32100: 'train_loss' was not in top 1
# Epoch 321, global step 32200: 'train_loss' was not in top 1
# Epoch 322, global step 32300: 'train_loss' was not in top 1
# Epoch 323, global step 32400: 'train_loss' was not in top 1
# Epoch 324, global step 32500: 'train_loss' was not in top 1
# Epoch 325, global step 32600: 'train_loss' was not in top 1
# Epoch 326, global step 32700: 'train_loss' was not in top 1
# Epoch 327, global step 32800: 'train_loss' was not in top 1
# Epoch 328, global step 32900: 'train_loss' was not in top 1
# Epoch 329, global step 33000: 'train_loss' was not in top 1
# Epoch 330, global step 33100: 'train_loss' was not in top 1
# Epoch 331, global step 33200: 'train_loss' was not in top 1
# Epoch 332, global step 33300: 'train_loss' was not in top 1
# Epoch 333, global step 33400: 'train_loss' was not in top 1
# Epoch 334, global step 33500: 'train_loss' was not in top 1
# Epoch 335, global step 33600: 'train_loss' was not in top 1
# Epoch 336, global step 33700: 'train_loss' was not in top 1
# Epoch 337, global step 33800: 'train_loss' was not in top 1
# Epoch 338, global step 33900: 'train_loss' was not in top 1
# Epoch 339, global step 34000: 'train_loss' was not in top 1
# Epoch 340, global step 34100: 'train_loss' was not in top 1
# Epoch 341, global step 34200: 'train_loss' was not in top 1
# Epoch 342, global step 34300: 'train_loss' was not in top 1
# Epoch 343, global step 34400: 'train_loss' was not in top 1
# Epoch 344, global step 34500: 'train_loss' was not in top 1
# Epoch 345, global step 34600: 'train_loss' was not in top 1
# Epoch 346, global step 34700: 'train_loss' was not in top 1
# Epoch 347, global step 34800: 'train_loss' was not in top 1
# Epoch 348, global step 34900: 'train_loss' was not in top 1
# Epoch 349, global step 35000: 'train_loss' was not in top 1
# C:\Users\Windows\AppData\Local\Programs\Python\Python311\Lib\site-packages\lightning\pytorch\trainer\call.py:54: Detected KeyboardInterrupt, attempting graceful shutdown...
# The mean prediction is not stored in the forecast data; the median is being returned instead. This behaviour may change in the future.
# Past Dynamic Features Training Shape: (20, 1762)
# Past Dynamic Features Test Shape: (20, 1)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df is your DataFrame with the data, and it's sorted by the index (date)
target_column = 'ETH-CAD_High'  # Ensure this matches your actual target column name
prediction_length = 1
# Assuming the DataFrame's index is a datetime index and sorted
end_training = df.index[-1]  # Assuming prediction_length is defined earlier

# Ensure forecast_start_date is a datetime object and exists in df.index
forecast_start_date = end_training 

# Plot the forecast and actual values starting from the forecast start date
plt.figure(figsize=(12, 6))

# Plot actual values from the start of the forecast
actuals_start_index = df.index.get_loc(forecast_start_date)
plt.plot(df.index[actuals_start_index:], df[target_column][actuals_start_index:], label="True values", color="black")

# Assuming mean_predictions, p10_predictions, p50_predictions, p90_predictions are defined from the forecasting model
# Plot forecast values
forecast_index = pd.date_range(start=forecast_start_date, periods=prediction_length, freq=freq)  # freq should be defined as per your data's frequency
plt.plot(forecast_index, mean_predictions, color='red', linestyle='--', label="Forecast (mean)")
plt.fill_between(forecast_index, p10_predictions, p90_predictions, color='red', alpha=0.3, label="P10-P90 interval")
plt.fill_between(forecast_index, p10_predictions, p50_predictions, color='red', alpha=0.5, label="P10-P50 interval")
plt.fill_between(forecast_index, p50_predictions, p90_predictions, color='red', alpha=0.5, label="P50-P90 interval")

# Add a vertical line and other plot elements
plt.axvline(x=forecast_start_date, color='blue', linestyle='--', label='Start of forecast')
plt.legend(loc="upper left", fontsize="large")
plt.title('Forecast vs Actual Values from Forecast Start')
plt.xlabel('Date')
plt.ylabel('Value')
plt.tight_layout()
plt.show()

# %%
last_row = df.iloc[-1:, :]
last_row
# Out:
#             ETH-CAD_High  ETH-CAD_Low  BTC-CAD_High   BTC-CAD_Low  \
# 2024-02-05   3111.508301  3059.306396  58076.230469  57048.390625
#
#             AdrBalNtv0.01Cnt  AdrBalNtv0.1Cnt  AdrBalNtv1Cnt  AdrBalNtv10Cnt  \
# 2024-02-05          24713162          5146142        1728854          344070
#
#             BlkSizeMeanByte    CapRealUSD  ...    FlowInExNtv   FlowOutExNtv  \
# 2024-02-05    161689.073003  1.664033e+11  ...  230617.498979  369227.537384
#
#             FlowTfrFromExCnt  GasUsedTxMean       NDF     SplyAct1d  \
# 2024-02-05             95967   96329.680096  0.677587  1.135770e+07
#
#             SplyActPct1yr    TxCnt  VelCur1yr  Global_Liquidity_Index
# 2024-02-05      35.852078  1120237   6.044788           123316.901832
#
# [1 rows x 21 columns]

# %%
p50_predictions
# Out:
# array([3111.5117], dtype=float32)

# %%
# Function to calculate sMAPE
def calculate_smape(forecasts, actuals):
    return 100 * np.mean(2 * np.abs(forecasts - actuals) / (np.abs(actuals) + np.abs(forecasts)))

# Calculate standard evaluation metrics for mean predictions
mae = np.mean(np.abs(mean_predictions - actuals))
rmse = np.sqrt(np.mean(np.square(mean_predictions - actuals)))
mape = np.mean(np.abs((mean_predictions - actuals) / actuals)) * 100
smape = calculate_smape(mean_predictions, actuals)

# Calculate the percentage of actuals within the 10th to 90th percentile range
within_range = np.sum((actuals >= p10_predictions) & (actuals <= p90_predictions)) / len(actuals) * 100

print("Evaluation Metrics for Mean Predictions:")
print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"MAPE: {mape:.2f}%")
print(f"sMAPE: {smape:.2f}%")
print(f"Percentage of Actuals within P10-P90 Interval: {within_range:.2f}%")
# Out:
# Evaluation Metrics for Mean Predictions:
# MAE: 0.00
# RMSE: 0.00
# MAPE: 0.00%
# sMAPE: 0.00%
# Percentage of Actuals within P10-P90 Interval: 0.00%

# %%
import os
import torch

# Define a path to save the model
model_save_path = 'vernon_high.pth'

# Assuming 'predictor' is the trained model from DeepAREstimator
torch.save(predictor, model_save_path)

print(f'Model saved to {model_save_path}')
# Out:
# Model saved to vernon_high.pth
