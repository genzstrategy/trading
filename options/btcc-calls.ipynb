# %%
import yfinance as yf
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import pytz
from scipy.stats import norm

# binomial_tree_option_priceModel
from scipy.stats import norm
import numpy as np

# Binomial Options Pricing Model for American Call Option
def binomial_tree_option_price(S, K, T, r, sigma, N=1000):
    dt = T / N
    u = np.exp(sigma * np.sqrt(dt))
    d = 1 / u
    p = (np.exp(r * dt) - d) / (u - d)
    
    prices = np.zeros(N + 1)
    prices[0] = S * d ** N
    for i in range(1, N + 1):
        prices[i] = prices[i - 1] * u / d
    
    option_values = np.maximum(prices - K, 0)
    
    for i in range(N - 1, -1, -1):
        for j in range(i + 1):
            option_values[j] = (p * option_values[j + 1] + (1 - p) * option_values[j]) * np.exp(-r * dt)
            option_values[j] = np.maximum(option_values[j], prices[j] - K)
    
    return option_values[0]

def calculate_greeks(S, K, T, r, sigma, N=100):
    base_price = binomial_tree_option_price(S, K, T, r, sigma, N)
    
    # Delta
    delta_S = 0.01 * S
    price_up = binomial_tree_option_price(S + delta_S, K, T, r, sigma, N)
    price_down = binomial_tree_option_price(S - delta_S, K, T, r, sigma, N)
    delta = (price_up - price_down) / (2 * delta_S)
    
    # Gamma
    price_up_up = binomial_tree_option_price(S + 2 * delta_S, K, T, r, sigma, N)
    gamma = (price_up_up - 2 * base_price + price_down) / (delta_S ** 2)
    
    # Theta
    delta_T = 1/365
    price_T_up = binomial_tree_option_price(S, K, T + delta_T, r, sigma, N)
    theta = (price_T_up - base_price) / delta_T
    
    # Vega
    delta_sigma = 0.01 * sigma
    price_sigma_up = binomial_tree_option_price(S, K, T, r, sigma + delta_sigma, N)
    vega = (price_sigma_up - base_price) / delta_sigma
    
    # Rho
    delta_r = 0.01
    price_r_up = binomial_tree_option_price(S, K, T, r + delta_r, sigma, N)
    rho = (price_r_up - base_price) / delta_r
    
    return delta, gamma, theta, vega, rho

# Retrieve historical data
ticker = "BTCC-B.TO"
start_time = (datetime.now(pytz.timezone('US/Pacific')) - timedelta(days=365*4)).strftime('%Y-%m-%d')
end_time = (datetime.now(pytz.timezone('US/Pacific'))).strftime('%Y-%m-%d')
data = yf.download(ticker, start=start_time, end=end_time, interval="1d")[['Close']]
data['Daily_Return'] = data['Close'].pct_change()
daily_volatility = data['Daily_Return'].std()
annualized_volatility = daily_volatility * np.sqrt(252)

# Risk-free rate (annualized)
risk_free_rate = 0.05  # Example rate, adjust as needed

# Current stock price
current_stock_price = data['Close'].iloc[-1]

# Calculate the next 4 Fridays from today, spaced two weeks apart
today = datetime.now(pytz.timezone('US/Pacific')).date()
friday_dates = [today + timedelta(days=((4 - today.weekday()) % 7) + 30*i) for i in range(12)]

# Generate a range of strike prices from -50% to +50% of the current stock price by 5% increments
strike_price_range = np.arange(0, 1.0, 0.05)  # Ends at 0.55 to include 50%
strike_prices = [current_stock_price * (1 + x) for x in strike_price_range]

# Print options prices with improved format
last_expiry_date = None
for expiry_date in friday_dates:
    days_to_expiration = (expiry_date - today).days / 365  # Convert days to years
    if expiry_date != last_expiry_date:
        print(f"\nExpiration Date: {expiry_date.strftime('%Y-%m-%d')}")
        last_expiry_date = expiry_date
    for strike_price in strike_prices:
        call_option_price = binomial_tree_option_price(current_stock_price, strike_price, days_to_expiration, risk_free_rate, annualized_volatility)
        delta, gamma, theta, vega, rho = calculate_greeks(current_stock_price, strike_price, days_to_expiration, risk_free_rate, annualized_volatility)
        print(f"  Strike Price: {strike_price:.2f}, Call Option Price: {call_option_price:.2f}, Delta: {delta:.2f}, Gamma: {gamma:.2f}, Theta: {theta:.2f}, Vega: {vega:.2f}, Rho: {rho:.2f}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\falty\AppData\Local\Temp\ipykernel_6848\615037854.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Daily_Return'] = data['Close'].pct_change()
# Expiration Date: 2024-03-01
#   Strike Price: 10.53, Call Option Price: 0.23, Delta: 0.51, Gamma: 6.69, Theta: 12.99, Vega: 0.38, Rho: 0.04
#   Strike Price: 11.06, Call Option Price: 0.06, Delta: 0.19, Gamma: 3.10, Theta: 9.13, Vega: 0.26, Rho: 0.02
#   Strike Price: 11.58, Call Option Price: 0.01, Delta: 0.04, Gamma: 0.83, Theta: 3.59, Vega: 0.09, Rho: 0.00
#   Strike Price: 12.11, Call Option Price: 0.00, Delta: 0.01, Gamma: 0.13, Theta: 0.78, Vega: 0.02, Rho: 0.00
#   Strike Price: 12.64, Call Option Price: 0.00, Delta: 0.00, Gamma: 0.01, Theta: 0.11, Vega: 0.00, Rho: 0.00
#   Strike Price: 13.16, Call Option Price: 0.00, Delta: 0.00, Gamma: 0.00, Theta: 0.01, Vega: 0.00, Rho: 0.00
#   Strike Price: 13.69, Call Option Price: 0.00, Delta: 0.00, Gamma: 0.00, Theta: 0.00, Vega: 0.00, Rho: 0.00
#   Strike Price: 14.22, Call Option Price: 0.00, Delta: 0.00, Gamma: 0.00, Theta: 0.00, Vega: 0.00, Rho: 0.00
#   Strike Price: 14.74, Call Option Price: 0.00, Delta: 0.00, Gamma: 0.00, Theta: 0.00, Vega: 0.00, Rho: 0.00
#   Strike Price: 15.27, Call Option Price: 0.00, Delta: 0.00, Gamma: 0.00, Theta: 0.00, Vega: 0.00, Rho: 0.00
#   Strike Price: 15.79, Call Option Price: 0.00, Delta: 0.00, Gamma: 0.00, Theta: 0.00, Vega: 0.00, Rho: 0.00
#   Strike Price: 16.32, Call Option Price: 0.00, Delta: 0.00, Gamma: 0.00, Theta: 0.00, Vega: 0.00, Rho: 0.00
#   Strike Price: 16.85, Call Option Price: 0.00, Delta: 0.00, Gamma: 0.00, Theta: 0.00, Vega: 0.00, Rho: 0.00
#   Strike Price: 17.37, Call Option Price: 0.00, Delta: 0.00, Gamma: 0.00, Theta: 0.00, Vega: 0.00, Rho: 0.00
#   Strike Price: 17.90, Call Option Price: 0.00, Delta: 0.00, Gamma: 0.00, Theta: 0.00, Vega: 0.00, Rho: 0.00
#   Strike Price: 18.43, Call Option Price: 0.00, Delta: 0.00, Gamma: 0.00, Theta: 0.00, Vega: 0.00, Rho: 0.00
#   Strike Price: 18.95, Call Option Price: 0.00, Delta: 0.00, Gamma: 0.00, Theta: 0.00, Vega: 0.00, Rho: 0.00
#   Strike Price: 19.48, Call Option Price: 0.00, Delta: 0.00, Gamma: 0.00, Theta: 0.00, Vega: 0.00, Rho: 0.00
#   Strike Price: 20.01, Call Option Price: 0.00, Delta: 0.00, Gamma: 0.00, Theta: 0.00, Vega: 0.00, Rho: 0.00
#   Strike Price: 20.53, Call Option Price: 0.00, Delta: 0.00, Gamma: 0.00, Theta: 0.00, Vega: 0.00, Rho: 0.00
#
# Expiration Date: 2024-03-31
#   Strike Price: 10.53, Call Option Price: 0.77, Delta: 0.55, Gamma: 6.31, Theta: 4.33, Vega: 1.25, Rho: 0.45
#   Strike Price: 11.06, Call Option Price: 0.55, Delta: 0.43, Gamma: 4.57, Theta: 4.25, Vega: 1.24, Rho: 0.37
#   Strike Price: 11.58, Call Option Price: 0.38, Delta: 0.35, Gamma: 3.33, Theta: 4.01, Vega: 1.18, Rho: 0.29
#   Strike Price: 12.11, Call Option Price: 0.26, Delta: 0.26, Gamma: 3.07, Theta: 3.63, Vega: 1.08, Rho: 0.22
#   Strike Price: 12.64, Call Option Price: 0.17, Delta: 0.18, Gamma: 2.37, Theta: 2.60, Vega: 0.77, Rho: 0.16
#   Strike Price: 13.16, Call Option Price: 0.11, Delta: 0.12, Gamma: 1.59, Theta: 2.09, Vega: 0.62, Rho: 0.11
#   Strike Price: 13.69, Call Option Price: 0.07, Delta: 0.08, Gamma: 1.04, Theta: 1.61, Vega: 0.48, Rho: 0.08
#   Strike Price: 14.22, Call Option Price: 0.04, Delta: 0.06, Gamma: 0.67, Theta: 1.19, Vega: 0.36, Rho: 0.05
#   Strike Price: 14.74, Call Option Price: 0.03, Delta: 0.04, Gamma: 0.44, Theta: 0.85, Vega: 0.25, Rho: 0.03
#   Strike Price: 15.27, Call Option Price: 0.02, Delta: 0.02, Gamma: 0.29, Theta: 0.58, Vega: 0.17, Rho: 0.02
#   Strike Price: 15.79, Call Option Price: 0.01, Delta: 0.01, Gamma: 0.20, Theta: 0.38, Vega: 0.11, Rho: 0.01
#   Strike Price: 16.32, Call Option Price: 0.01, Delta: 0.01, Gamma: 0.14, Theta: 0.24, Vega: 0.07, Rho: 0.01
#   Strike Price: 16.85, Call Option Price: 0.00, Delta: 0.01, Gamma: 0.09, Theta: 0.16, Vega: 0.04, Rho: 0.01
#   Strike Price: 17.37, Call Option Price: 0.00, Delta: 0.00, Gamma: 0.06, Theta: 0.14, Vega: 0.04, Rho: 0.00
#   Strike Price: 17.90, Call Option Price: 0.00, Delta: 0.00, Gamma: 0.03, Theta: 0.08, Vega: 0.02, Rho: 0.00
#   Strike Price: 18.43, Call Option Price: 0.00, Delta: 0.00, Gamma: 0.01, Theta: 0.05, Vega: 0.01, Rho: 0.00
#   Strike Price: 18.95, Call Option Price: 0.00, Delta: 0.00, Gamma: 0.01, Theta: 0.02, Vega: 0.01, Rho: 0.00
#   Strike Price: 19.48, Call Option Price: 0.00, Delta: 0.00, Gamma: 0.01, Theta: 0.01, Vega: 0.00, Rho: 0.00
#   Strike Price: 20.01, Call Option Price: 0.00, Delta: 0.00, Gamma: 0.00, Theta: 0.01, Vega: 0.00, Rho: 0.00
#   Strike Price: 20.53, Call Option Price: 0.00, Delta: 0.00, Gamma: 0.00, Theta: 0.01, Vega: 0.00, Rho: 0.00
#
# Expiration Date: 2024-04-30
#   Strike Price: 10.53, Call Option Price: 1.08, Delta: 0.56, Gamma: 6.46, Theta: 3.19, Vega: 1.72, Rho: 0.84
#   Strike Price: 11.06, Call Option Price: 0.85, Delta: 0.49, Gamma: 5.68, Theta: 3.25, Vega: 1.77, Rho: 0.73
#   Strike Price: 11.58, Call Option Price: 0.67, Delta: 0.42, Gamma: 4.70, Theta: 3.19, Vega: 1.76, Rho: 0.63
#   Strike Price: 12.11, Call Option Price: 0.52, Delta: 0.36, Gamma: 3.60, Theta: 3.01, Vega: 1.67, Rho: 0.53
#   Strike Price: 12.64, Call Option Price: 0.40, Delta: 0.29, Gamma: 2.79, Theta: 2.73, Vega: 1.52, Rho: 0.44
#   Strike Price: 13.16, Call Option Price: 0.31, Delta: 0.23, Gamma: 2.18, Theta: 2.38, Vega: 1.33, Rho: 0.36
#   Strike Price: 13.69, Call Option Price: 0.23, Delta: 0.17, Gamma: 1.87, Theta: 2.00, Vega: 1.11, Rho: 0.29
#   Strike Price: 14.22, Call Option Price: 0.17, Delta: 0.14, Gamma: 1.91, Theta: 1.61, Vega: 0.90, Rho: 0.23
#   Strike Price: 14.74, Call Option Price: 0.13, Delta: 0.12, Gamma: 1.24, Theta: 1.63, Vega: 0.92, Rho: 0.18
#   Strike Price: 15.27, Call Option Price: 0.10, Delta: 0.09, Gamma: 0.85, Theta: 1.26, Vega: 0.71, Rho: 0.15
#   Strike Price: 15.79, Call Option Price: 0.07, Delta: 0.06, Gamma: 0.83, Theta: 0.93, Vega: 0.52, Rho: 0.11
#   Strike Price: 16.32, Call Option Price: 0.05, Delta: 0.06, Gamma: 0.66, Theta: 0.94, Vega: 0.54, Rho: 0.09
#   Strike Price: 16.85, Call Option Price: 0.04, Delta: 0.04, Gamma: 0.38, Theta: 0.67, Vega: 0.38, Rho: 0.07
#   Strike Price: 17.37, Call Option Price: 0.03, Delta: 0.03, Gamma: 0.42, Theta: 0.46, Vega: 0.26, Rho: 0.05
#   Strike Price: 17.90, Call Option Price: 0.02, Delta: 0.03, Gamma: 0.24, Theta: 0.46, Vega: 0.26, Rho: 0.04
#   Strike Price: 18.43, Call Option Price: 0.02, Delta: 0.02, Gamma: 0.18, Theta: 0.30, Vega: 0.17, Rho: 0.03
#   Strike Price: 18.95, Call Option Price: 0.01, Delta: 0.01, Gamma: 0.18, Theta: 0.31, Vega: 0.17, Rho: 0.02
#   Strike Price: 19.48, Call Option Price: 0.01, Delta: 0.01, Gamma: 0.09, Theta: 0.19, Vega: 0.11, Rho: 0.02
#   Strike Price: 20.01, Call Option Price: 0.01, Delta: 0.01, Gamma: 0.13, Theta: 0.19, Vega: 0.11, Rho: 0.01
#   Strike Price: 20.53, Call Option Price: 0.00, Delta: 0.01, Gamma: 0.05, Theta: 0.12, Vega: 0.07, Rho: 0.01
#
# Expiration Date: 2024-05-30
#   Strike Price: 10.53, Call Option Price: 1.31, Delta: 0.58, Gamma: 6.58, Theta: 2.65, Vega: 2.08, Rho: 1.21
#   Strike Price: 11.06, Call Option Price: 1.09, Delta: 0.54, Gamma: 5.10, Theta: 2.70, Vega: 2.14, Rho: 1.10
#   Strike Price: 11.58, Call Option Price: 0.90, Delta: 0.46, Gamma: 4.34, Theta: 2.66, Vega: 2.12, Rho: 0.98
#   Strike Price: 12.11, Call Option Price: 0.74, Delta: 0.38, Gamma: 3.60, Theta: 2.51, Vega: 2.01, Rho: 0.87
#   Strike Price: 12.64, Call Option Price: 0.61, Delta: 0.33, Gamma: 4.13, Theta: 2.28, Vega: 1.84, Rho: 0.75
#   Strike Price: 13.16, Call Option Price: 0.50, Delta: 0.31, Gamma: 2.91, Theta: 2.32, Vega: 1.88, Rho: 0.66
#   Strike Price: 13.69, Call Option Price: 0.40, Delta: 0.24, Gamma: 2.28, Theta: 2.02, Vega: 1.65, Rho: 0.56
#   Strike Price: 14.22, Call Option Price: 0.33, Delta: 0.21, Gamma: 2.81, Theta: 1.98, Vega: 1.65, Rho: 0.48
#   Strike Price: 14.74, Call Option Price: 0.26, Delta: 0.18, Gamma: 1.73, Theta: 1.72, Vega: 1.41, Rho: 0.41
#   Strike Price: 15.27, Call Option Price: 0.21, Delta: 0.13, Gamma: 1.64, Theta: 1.39, Vega: 1.13, Rho: 0.34
#   Strike Price: 15.79, Call Option Price: 0.17, Delta: 0.13, Gamma: 1.27, Theta: 1.40, Vega: 1.16, Rho: 0.29
#   Strike Price: 16.32, Call Option Price: 0.14, Delta: 0.10, Gamma: 0.95, Theta: 1.09, Vega: 0.89, Rho: 0.24
#   Strike Price: 16.85, Call Option Price: 0.11, Delta: 0.09, Gamma: 0.92, Theta: 1.10, Vega: 0.91, Rho: 0.20
#   Strike Price: 17.37, Call Option Price: 0.09, Delta: 0.07, Gamma: 0.62, Theta: 0.82, Vega: 0.67, Rho: 0.16
#   Strike Price: 17.90, Call Option Price: 0.07, Delta: 0.06, Gamma: 0.64, Theta: 0.82, Vega: 0.69, Rho: 0.14
#   Strike Price: 18.43, Call Option Price: 0.06, Delta: 0.04, Gamma: 0.41, Theta: 0.59, Vega: 0.49, Rho: 0.11
#   Strike Price: 18.95, Call Option Price: 0.04, Delta: 0.04, Gamma: 0.41, Theta: 0.59, Vega: 0.49, Rho: 0.09
#   Strike Price: 19.48, Call Option Price: 0.03, Delta: 0.03, Gamma: 0.33, Theta: 0.41, Vega: 0.34, Rho: 0.07
#   Strike Price: 20.01, Call Option Price: 0.03, Delta: 0.03, Gamma: 0.26, Theta: 0.41, Vega: 0.34, Rho: 0.06
#   Strike Price: 20.53, Call Option Price: 0.02, Delta: 0.02, Gamma: 0.28, Theta: 0.27, Vega: 0.22, Rho: 0.05
#
# Expiration Date: 2024-06-29
#   Strike Price: 10.53, Call Option Price: 1.52, Delta: 0.59, Gamma: 6.68, Theta: 2.32, Vega: 2.37, Rho: 1.58
#   Strike Price: 11.06, Call Option Price: 1.30, Delta: 0.55, Gamma: 5.21, Theta: 2.37, Vega: 2.45, Rho: 1.45
#   Strike Price: 11.58, Call Option Price: 1.11, Delta: 0.47, Gamma: 4.45, Theta: 2.33, Vega: 2.42, Rho: 1.33
#   Strike Price: 12.11, Call Option Price: 0.94, Delta: 0.42, Gamma: 5.06, Theta: 2.20, Vega: 2.30, Rho: 1.20
#   Strike Price: 12.64, Call Option Price: 0.80, Delta: 0.39, Gamma: 3.71, Theta: 2.24, Vega: 2.37, Rho: 1.08
#   Strike Price: 13.16, Call Option Price: 0.68, Delta: 0.32, Gamma: 3.26, Theta: 2.04, Vega: 2.15, Rho: 0.96
#   Strike Price: 13.69, Call Option Price: 0.57, Delta: 0.32, Gamma: 3.00, Theta: 2.07, Vega: 2.21, Rho: 0.86
#   Strike Price: 14.22, Call Option Price: 0.48, Delta: 0.25, Gamma: 2.36, Theta: 1.81, Vega: 1.93, Rho: 0.76
#   Strike Price: 14.74, Call Option Price: 0.40, Delta: 0.24, Gamma: 2.46, Theta: 1.83, Vega: 1.97, Rho: 0.66
#   Strike Price: 15.27, Call Option Price: 0.34, Delta: 0.19, Gamma: 1.80, Theta: 1.54, Vega: 1.65, Rho: 0.58
#   Strike Price: 15.79, Call Option Price: 0.28, Delta: 0.19, Gamma: 1.89, Theta: 1.56, Vega: 1.69, Rho: 0.51
#   Strike Price: 16.32, Call Option Price: 0.24, Delta: 0.14, Gamma: 1.33, Theta: 1.26, Vega: 1.35, Rho: 0.44
#   Strike Price: 16.85, Call Option Price: 0.20, Delta: 0.14, Gamma: 1.33, Theta: 1.27, Vega: 1.38, Rho: 0.38
#   Strike Price: 17.37, Call Option Price: 0.17, Delta: 0.10, Gamma: 1.02, Theta: 0.98, Vega: 1.06, Rho: 0.33
#   Strike Price: 17.90, Call Option Price: 0.14, Delta: 0.10, Gamma: 0.95, Theta: 1.00, Vega: 1.08, Rho: 0.29
#   Strike Price: 18.43, Call Option Price: 0.12, Delta: 0.07, Gamma: 1.01, Theta: 0.74, Vega: 0.80, Rho: 0.24
#   Strike Price: 18.95, Call Option Price: 0.10, Delta: 0.07, Gamma: 0.66, Theta: 0.75, Vega: 0.81, Rho: 0.21
#   Strike Price: 19.48, Call Option Price: 0.08, Delta: 0.06, Gamma: 0.76, Theta: 0.76, Vega: 0.83, Rho: 0.18
#   Strike Price: 20.01, Call Option Price: 0.07, Delta: 0.05, Gamma: 0.44, Theta: 0.54, Vega: 0.59, Rho: 0.16
#   Strike Price: 20.53, Call Option Price: 0.06, Delta: 0.05, Gamma: 0.44, Theta: 0.54, Vega: 0.60, Rho: 0.13
#
# Expiration Date: 2024-07-29
#   Strike Price: 10.53, Call Option Price: 1.70, Delta: 0.60, Gamma: 6.77, Theta: 2.09, Vega: 2.63, Rho: 1.93
#   Strike Price: 11.06, Call Option Price: 1.48, Delta: 0.56, Gamma: 5.30, Theta: 2.13, Vega: 2.71, Rho: 1.80
#   Strike Price: 11.58, Call Option Price: 1.29, Delta: 0.48, Gamma: 4.66, Theta: 2.10, Vega: 2.69, Rho: 1.67
#   Strike Price: 12.11, Call Option Price: 1.12, Delta: 0.48, Gamma: 4.55, Theta: 2.14, Vega: 2.76, Rho: 1.54
#   Strike Price: 12.64, Call Option Price: 0.97, Delta: 0.40, Gamma: 3.80, Theta: 2.02, Vega: 2.62, Rho: 1.41
#   Strike Price: 13.16, Call Option Price: 0.84, Delta: 0.39, Gamma: 3.98, Theta: 2.06, Vega: 2.69, Rho: 1.28
#   Strike Price: 13.69, Call Option Price: 0.73, Delta: 0.33, Gamma: 3.09, Theta: 1.87, Vega: 2.45, Rho: 1.16
#   Strike Price: 14.22, Call Option Price: 0.63, Delta: 0.32, Gamma: 3.26, Theta: 1.90, Vega: 2.51, Rho: 1.05
#   Strike Price: 14.74, Call Option Price: 0.54, Delta: 0.26, Gamma: 2.44, Theta: 1.66, Vega: 2.19, Rho: 0.95
#   Strike Price: 15.27, Call Option Price: 0.47, Delta: 0.26, Gamma: 2.44, Theta: 1.68, Vega: 2.24, Rho: 0.85
#   Strike Price: 15.79, Call Option Price: 0.40, Delta: 0.20, Gamma: 1.87, Theta: 1.41, Vega: 1.87, Rho: 0.76
#   Strike Price: 16.32, Call Option Price: 0.35, Delta: 0.20, Gamma: 1.87, Theta: 1.43, Vega: 1.91, Rho: 0.68
#   Strike Price: 16.85, Call Option Price: 0.30, Delta: 0.15, Gamma: 1.94, Theta: 1.16, Vega: 1.53, Rho: 0.60
#   Strike Price: 17.37, Call Option Price: 0.26, Delta: 0.15, Gamma: 1.39, Theta: 1.17, Vega: 1.56, Rho: 0.54
#   Strike Price: 17.90, Call Option Price: 0.22, Delta: 0.14, Gamma: 1.48, Theta: 1.18, Vega: 1.59, Rho: 0.47
#   Strike Price: 18.43, Call Option Price: 0.19, Delta: 0.10, Gamma: 1.00, Theta: 0.92, Vega: 1.22, Rho: 0.42
#   Strike Price: 18.95, Call Option Price: 0.16, Delta: 0.10, Gamma: 1.00, Theta: 0.93, Vega: 1.25, Rho: 0.37
#   Strike Price: 19.48, Call Option Price: 0.14, Delta: 0.09, Gamma: 1.30, Theta: 0.94, Vega: 1.27, Rho: 0.33
#   Strike Price: 20.01, Call Option Price: 0.12, Delta: 0.07, Gamma: 0.69, Theta: 0.70, Vega: 0.93, Rho: 0.29
#   Strike Price: 20.53, Call Option Price: 0.11, Delta: 0.07, Gamma: 0.69, Theta: 0.70, Vega: 0.95, Rho: 0.26
#
# Expiration Date: 2024-08-28
#   Strike Price: 10.53, Call Option Price: 1.86, Delta: 0.61, Gamma: 6.85, Theta: 1.92, Vega: 2.86, Rho: 2.27
#   Strike Price: 11.06, Call Option Price: 1.65, Delta: 0.57, Gamma: 5.39, Theta: 1.96, Vega: 2.95, Rho: 2.14
#   Strike Price: 11.58, Call Option Price: 1.46, Delta: 0.49, Gamma: 5.30, Theta: 1.93, Vega: 2.92, Rho: 2.01
#   Strike Price: 12.11, Call Option Price: 1.29, Delta: 0.49, Gamma: 4.64, Theta: 1.96, Vega: 3.00, Rho: 1.87
#   Strike Price: 12.64, Call Option Price: 1.14, Delta: 0.41, Gamma: 4.32, Theta: 1.86, Vega: 2.85, Rho: 1.73
#   Strike Price: 13.16, Call Option Price: 1.00, Delta: 0.41, Gamma: 3.89, Theta: 1.89, Vega: 2.93, Rho: 1.60
#   Strike Price: 13.69, Call Option Price: 0.88, Delta: 0.33, Gamma: 3.88, Theta: 1.72, Vega: 2.66, Rho: 1.47
#   Strike Price: 14.22, Call Option Price: 0.77, Delta: 0.33, Gamma: 3.17, Theta: 1.75, Vega: 2.73, Rho: 1.35
#   Strike Price: 14.74, Call Option Price: 0.68, Delta: 0.30, Gamma: 3.83, Theta: 1.76, Vega: 2.78, Rho: 1.23
#   Strike Price: 15.27, Call Option Price: 0.60, Delta: 0.26, Gamma: 2.51, Theta: 1.55, Vega: 2.43, Rho: 1.13
#   Strike Price: 15.79, Call Option Price: 0.53, Delta: 0.26, Gamma: 2.51, Theta: 1.57, Vega: 2.48, Rho: 1.03
#   Strike Price: 16.32, Call Option Price: 0.46, Delta: 0.20, Gamma: 2.05, Theta: 1.32, Vega: 2.08, Rho: 0.93
#   Strike Price: 16.85, Call Option Price: 0.41, Delta: 0.20, Gamma: 1.93, Theta: 1.34, Vega: 2.12, Rho: 0.85
#   Strike Price: 17.37, Call Option Price: 0.36, Delta: 0.19, Gamma: 2.23, Theta: 1.35, Vega: 2.16, Rho: 0.76
#   Strike Price: 17.90, Call Option Price: 0.31, Delta: 0.15, Gamma: 1.44, Theta: 1.09, Vega: 1.73, Rho: 0.69
#   Strike Price: 18.43, Call Option Price: 0.28, Delta: 0.15, Gamma: 1.44, Theta: 1.11, Vega: 1.76, Rho: 0.63
#   Strike Price: 18.95, Call Option Price: 0.24, Delta: 0.13, Gamma: 1.80, Theta: 1.12, Vega: 1.79, Rho: 0.56
#   Strike Price: 19.48, Call Option Price: 0.21, Delta: 0.11, Gamma: 1.04, Theta: 0.87, Vega: 1.38, Rho: 0.51
#   Strike Price: 20.01, Call Option Price: 0.19, Delta: 0.11, Gamma: 1.04, Theta: 0.88, Vega: 1.40, Rho: 0.46
#   Strike Price: 20.53, Call Option Price: 0.16, Delta: 0.10, Gamma: 1.19, Theta: 0.88, Vega: 1.43, Rho: 0.41
#
# Expiration Date: 2024-09-27
#   Strike Price: 10.53, Call Option Price: 2.02, Delta: 0.61, Gamma: 6.92, Theta: 1.78, Vega: 3.07, Rho: 2.61
#   Strike Price: 11.06, Call Option Price: 1.81, Delta: 0.58, Gamma: 5.47, Theta: 1.82, Vega: 3.16, Rho: 2.47
#   Strike Price: 11.58, Call Option Price: 1.61, Delta: 0.52, Gamma: 5.88, Theta: 1.79, Vega: 3.13, Rho: 2.34
#   Strike Price: 12.11, Call Option Price: 1.44, Delta: 0.50, Gamma: 4.72, Theta: 1.83, Vega: 3.22, Rho: 2.20
#   Strike Price: 12.64, Call Option Price: 1.29, Delta: 0.45, Gamma: 5.41, Theta: 1.73, Vega: 3.19, Rho: 2.06
#   Strike Price: 13.16, Call Option Price: 1.15, Delta: 0.42, Gamma: 3.97, Theta: 1.76, Vega: 3.14, Rho: 1.92
#   Strike Price: 13.69, Call Option Price: 1.03, Delta: 0.42, Gamma: 3.98, Theta: 1.79, Vega: 3.22, Rho: 1.79
#   Strike Price: 14.22, Call Option Price: 0.91, Delta: 0.34, Gamma: 3.24, Theta: 1.63, Vega: 2.92, Rho: 1.66
#   Strike Price: 14.74, Call Option Price: 0.82, Delta: 0.34, Gamma: 3.24, Theta: 1.65, Vega: 2.99, Rho: 1.54
#   Strike Price: 15.27, Call Option Price: 0.73, Delta: 0.28, Gamma: 3.33, Theta: 1.45, Vega: 2.61, Rho: 1.42
#   Strike Price: 15.79, Call Option Price: 0.65, Delta: 0.27, Gamma: 2.58, Theta: 1.47, Vega: 2.66, Rho: 1.31
#   Strike Price: 16.32, Call Option Price: 0.58, Delta: 0.27, Gamma: 2.58, Theta: 1.49, Vega: 2.72, Rho: 1.20
#   Strike Price: 16.85, Call Option Price: 0.52, Delta: 0.21, Gamma: 2.20, Theta: 1.25, Vega: 2.27, Rho: 1.11
#   Strike Price: 17.37, Call Option Price: 0.46, Delta: 0.21, Gamma: 1.99, Theta: 1.27, Vega: 2.32, Rho: 1.02
#   Strike Price: 17.90, Call Option Price: 0.41, Delta: 0.21, Gamma: 1.99, Theta: 1.28, Vega: 2.36, Rho: 0.93
#   Strike Price: 18.43, Call Option Price: 0.37, Delta: 0.16, Gamma: 1.72, Theta: 1.03, Vega: 1.89, Rho: 0.85
#   Strike Price: 18.95, Call Option Price: 0.33, Delta: 0.16, Gamma: 1.49, Theta: 1.05, Vega: 1.92, Rho: 0.78
#   Strike Price: 19.48, Call Option Price: 0.29, Delta: 0.16, Gamma: 1.49, Theta: 1.06, Vega: 1.96, Rho: 0.71
#   Strike Price: 20.01, Call Option Price: 0.26, Delta: 0.12, Gamma: 1.62, Theta: 0.82, Vega: 1.50, Rho: 0.65
#   Strike Price: 20.53, Call Option Price: 0.23, Delta: 0.11, Gamma: 1.07, Theta: 0.83, Vega: 1.53, Rho: 0.60
#
# Expiration Date: 2024-10-27
#   Strike Price: 10.53, Call Option Price: 2.16, Delta: 0.62, Gamma: 6.99, Theta: 1.67, Vega: 3.26, Rho: 2.93
#   Strike Price: 11.06, Call Option Price: 1.95, Delta: 0.58, Gamma: 5.54, Theta: 1.71, Vega: 3.36, Rho: 2.80
#   Strike Price: 11.58, Call Option Price: 1.76, Delta: 0.55, Gamma: 6.18, Theta: 1.74, Vega: 3.46, Rho: 2.66
#   Strike Price: 12.11, Call Option Price: 1.59, Delta: 0.50, Gamma: 4.79, Theta: 1.71, Vega: 3.42, Rho: 2.52
#   Strike Price: 12.64, Call Option Price: 1.43, Delta: 0.50, Gamma: 4.79, Theta: 1.75, Vega: 3.52, Rho: 2.38
#   Strike Price: 13.16, Call Option Price: 1.29, Delta: 0.43, Gamma: 4.04, Theta: 1.65, Vega: 3.33, Rho: 2.24
#   Strike Price: 13.69, Call Option Price: 1.16, Delta: 0.43, Gamma: 4.04, Theta: 1.68, Vega: 3.42, Rho: 2.10
#   Strike Price: 14.22, Call Option Price: 1.05, Delta: 0.35, Gamma: 4.08, Theta: 1.53, Vega: 3.10, Rho: 1.97
#   Strike Price: 14.74, Call Option Price: 0.94, Delta: 0.35, Gamma: 3.31, Theta: 1.55, Vega: 3.18, Rho: 1.84
#   Strike Price: 15.27, Call Option Price: 0.85, Delta: 0.35, Gamma: 3.31, Theta: 1.58, Vega: 3.25, Rho: 1.71
#   Strike Price: 15.79, Call Option Price: 0.77, Delta: 0.28, Gamma: 2.78, Theta: 1.38, Vega: 2.83, Rho: 1.60
#   Strike Price: 16.32, Call Option Price: 0.69, Delta: 0.28, Gamma: 2.64, Theta: 1.40, Vega: 2.89, Rho: 1.49
#   Strike Price: 16.85, Call Option Price: 0.62, Delta: 0.28, Gamma: 2.64, Theta: 1.42, Vega: 2.95, Rho: 1.38
#   Strike Price: 17.37, Call Option Price: 0.56, Delta: 0.22, Gamma: 2.26, Theta: 1.19, Vega: 2.46, Rho: 1.28
#   Strike Price: 17.90, Call Option Price: 0.51, Delta: 0.22, Gamma: 2.04, Theta: 1.21, Vega: 2.51, Rho: 1.19
#   Strike Price: 18.43, Call Option Price: 0.46, Delta: 0.22, Gamma: 2.04, Theta: 1.22, Vega: 2.55, Rho: 1.10
#   Strike Price: 18.95, Call Option Price: 0.41, Delta: 0.17, Gamma: 2.23, Theta: 0.99, Vega: 2.04, Rho: 1.01
#   Strike Price: 19.48, Call Option Price: 0.37, Delta: 0.16, Gamma: 1.53, Theta: 1.00, Vega: 2.08, Rho: 0.94
#   Strike Price: 20.01, Call Option Price: 0.34, Delta: 0.16, Gamma: 1.53, Theta: 1.01, Vega: 2.12, Rho: 0.87
#   Strike Price: 20.53, Call Option Price: 0.31, Delta: 0.16, Gamma: 1.53, Theta: 1.02, Vega: 2.15, Rho: 0.80
#
# Expiration Date: 2024-11-26
#   Strike Price: 10.53, Call Option Price: 2.29, Delta: 0.63, Gamma: 7.05, Theta: 1.58, Vega: 3.43, Rho: 3.25
#   Strike Price: 11.06, Call Option Price: 2.09, Delta: 0.59, Gamma: 5.61, Theta: 1.61, Vega: 3.54, Rho: 3.11
#   Strike Price: 11.58, Call Option Price: 1.90, Delta: 0.58, Gamma: 5.81, Theta: 1.65, Vega: 3.65, Rho: 2.98
#   Strike Price: 12.11, Call Option Price: 1.73, Delta: 0.51, Gamma: 4.86, Theta: 1.62, Vega: 3.60, Rho: 2.84
#   Strike Price: 12.64, Call Option Price: 1.57, Delta: 0.51, Gamma: 4.86, Theta: 1.65, Vega: 3.70, Rho: 2.69
#   Strike Price: 13.16, Call Option Price: 1.43, Delta: 0.43, Gamma: 4.27, Theta: 1.56, Vega: 3.51, Rho: 2.55
#   Strike Price: 13.69, Call Option Price: 1.30, Delta: 0.43, Gamma: 4.11, Theta: 1.59, Vega: 3.60, Rho: 2.41
#   Strike Price: 14.22, Call Option Price: 1.18, Delta: 0.43, Gamma: 4.25, Theta: 1.61, Vega: 3.69, Rho: 2.27
#   Strike Price: 14.74, Call Option Price: 1.07, Delta: 0.36, Gamma: 3.38, Theta: 1.47, Vega: 3.35, Rho: 2.14
#   Strike Price: 15.27, Call Option Price: 0.97, Delta: 0.36, Gamma: 3.38, Theta: 1.49, Vega: 3.42, Rho: 2.01
#   Strike Price: 15.79, Call Option Price: 0.89, Delta: 0.34, Gamma: 3.69, Theta: 1.51, Vega: 3.50, Rho: 1.89
#   Strike Price: 16.32, Call Option Price: 0.81, Delta: 0.28, Gamma: 2.70, Theta: 1.33, Vega: 3.04, Rho: 1.77
#   Strike Price: 16.85, Call Option Price: 0.73, Delta: 0.28, Gamma: 2.70, Theta: 1.34, Vega: 3.11, Rho: 1.66
#   Strike Price: 17.37, Call Option Price: 0.67, Delta: 0.28, Gamma: 2.70, Theta: 1.36, Vega: 3.17, Rho: 1.55
#   Strike Price: 17.90, Call Option Price: 0.61, Delta: 0.22, Gamma: 2.27, Theta: 1.14, Vega: 2.64, Rho: 1.45
#   Strike Price: 18.43, Call Option Price: 0.55, Delta: 0.22, Gamma: 2.09, Theta: 1.16, Vega: 2.69, Rho: 1.36
#   Strike Price: 18.95, Call Option Price: 0.51, Delta: 0.22, Gamma: 2.09, Theta: 1.17, Vega: 2.74, Rho: 1.26
#   Strike Price: 19.48, Call Option Price: 0.46, Delta: 0.20, Gamma: 2.55, Theta: 1.19, Vega: 2.79, Rho: 1.17
#   Strike Price: 20.01, Call Option Price: 0.42, Delta: 0.17, Gamma: 1.57, Theta: 0.96, Vega: 2.23, Rho: 1.10
#   Strike Price: 20.53, Call Option Price: 0.38, Delta: 0.17, Gamma: 1.57, Theta: 0.97, Vega: 2.27, Rho: 1.03
#
# Expiration Date: 2024-12-26
#   Strike Price: 10.53, Call Option Price: 2.42, Delta: 0.64, Gamma: 7.10, Theta: 1.50, Vega: 3.59, Rho: 3.56
#   Strike Price: 11.06, Call Option Price: 2.22, Delta: 0.60, Gamma: 5.68, Theta: 1.53, Vega: 3.71, Rho: 3.43
#   Strike Price: 11.58, Call Option Price: 2.03, Delta: 0.60, Gamma: 5.68, Theta: 1.56, Vega: 3.82, Rho: 3.29
#   Strike Price: 12.11, Call Option Price: 1.86, Delta: 0.52, Gamma: 4.93, Theta: 1.54, Vega: 3.77, Rho: 3.15
#   Strike Price: 12.64, Call Option Price: 1.70, Delta: 0.52, Gamma: 4.93, Theta: 1.57, Vega: 3.88, Rho: 3.01
#   Strike Price: 13.16, Call Option Price: 1.56, Delta: 0.45, Gamma: 5.18, Theta: 1.49, Vega: 3.68, Rho: 2.86
#   Strike Price: 13.69, Call Option Price: 1.42, Delta: 0.44, Gamma: 4.18, Theta: 1.51, Vega: 3.77, Rho: 2.72
#   Strike Price: 14.22, Call Option Price: 1.30, Delta: 0.44, Gamma: 4.18, Theta: 1.54, Vega: 3.86, Rho: 2.58
#   Strike Price: 14.74, Call Option Price: 1.19, Delta: 0.36, Gamma: 4.04, Theta: 1.40, Vega: 3.51, Rho: 2.44
#   Strike Price: 15.27, Call Option Price: 1.09, Delta: 0.36, Gamma: 3.44, Theta: 1.42, Vega: 3.58, Rho: 2.31
#   Strike Price: 15.79, Call Option Price: 1.00, Delta: 0.36, Gamma: 3.44, Theta: 1.44, Vega: 3.66, Rho: 2.18
#   Strike Price: 16.32, Call Option Price: 0.92, Delta: 0.31, Gamma: 3.76, Theta: 1.26, Vega: 3.19, Rho: 2.06
#   Strike Price: 16.85, Call Option Price: 0.84, Delta: 0.29, Gamma: 2.76, Theta: 1.28, Vega: 3.25, Rho: 1.94
#   Strike Price: 17.37, Call Option Price: 0.77, Delta: 0.29, Gamma: 2.76, Theta: 1.30, Vega: 3.32, Rho: 1.83
#   Strike Price: 17.90, Call Option Price: 0.71, Delta: 0.29, Gamma: 2.76, Theta: 1.31, Vega: 3.38, Rho: 1.72
#   Strike Price: 18.43, Call Option Price: 0.65, Delta: 0.23, Gamma: 2.23, Theta: 1.10, Vega: 2.82, Rho: 1.62
#   Strike Price: 18.95, Call Option Price: 0.60, Delta: 0.23, Gamma: 2.14, Theta: 1.12, Vega: 2.87, Rho: 1.52
#   Strike Price: 19.48, Call Option Price: 0.55, Delta: 0.23, Gamma: 2.14, Theta: 1.13, Vega: 2.92, Rho: 1.43
#   Strike Price: 20.01, Call Option Price: 0.51, Delta: 0.22, Gamma: 2.28, Theta: 1.14, Vega: 2.97, Rho: 1.34
#   Strike Price: 20.53, Call Option Price: 0.47, Delta: 0.17, Gamma: 1.69, Theta: 0.92, Vega: 2.37, Rho: 1.26
#
# Expiration Date: 2025-01-25
#   Strike Price: 10.53, Call Option Price: 2.54, Delta: 0.64, Gamma: 7.16, Theta: 1.43, Vega: 3.74, Rho: 3.86
#   Strike Price: 11.06, Call Option Price: 2.34, Delta: 0.60, Gamma: 5.74, Theta: 1.46, Vega: 3.86, Rho: 3.73
#   Strike Price: 11.58, Call Option Price: 2.15, Delta: 0.60, Gamma: 5.74, Theta: 1.49, Vega: 3.98, Rho: 3.60
#   Strike Price: 12.11, Call Option Price: 1.98, Delta: 0.53, Gamma: 4.99, Theta: 1.47, Vega: 3.93, Rho: 3.46
#   Strike Price: 12.64, Call Option Price: 1.82, Delta: 0.53, Gamma: 4.99, Theta: 1.50, Vega: 4.04, Rho: 3.31
#   Strike Price: 13.16, Call Option Price: 1.68, Delta: 0.50, Gamma: 5.47, Theta: 1.52, Vega: 4.15, Rho: 3.17
#   Strike Price: 13.69, Call Option Price: 1.55, Delta: 0.45, Gamma: 4.24, Theta: 1.44, Vega: 3.93, Rho: 3.03
#   Strike Price: 14.22, Call Option Price: 1.42, Delta: 0.45, Gamma: 4.24, Theta: 1.47, Vega: 4.02, Rho: 2.89
#   Strike Price: 14.74, Call Option Price: 1.31, Delta: 0.42, Gamma: 4.69, Theta: 1.49, Vega: 4.12, Rho: 2.75
#   Strike Price: 15.27, Call Option Price: 1.21, Delta: 0.37, Gamma: 3.50, Theta: 1.36, Vega: 3.74, Rho: 2.61
#   Strike Price: 15.79, Call Option Price: 1.12, Delta: 0.37, Gamma: 3.50, Theta: 1.38, Vega: 3.82, Rho: 2.48
#   Strike Price: 16.32, Call Option Price: 1.03, Delta: 0.37, Gamma: 3.50, Theta: 1.40, Vega: 3.90, Rho: 2.35
#   Strike Price: 16.85, Call Option Price: 0.95, Delta: 0.30, Gamma: 3.07, Theta: 1.22, Vega: 3.39, Rho: 2.23
#   Strike Price: 17.37, Call Option Price: 0.88, Delta: 0.30, Gamma: 2.81, Theta: 1.24, Vega: 3.46, Rho: 2.11
#   Strike Price: 17.90, Call Option Price: 0.81, Delta: 0.30, Gamma: 2.81, Theta: 1.26, Vega: 3.52, Rho: 2.00
#   Strike Price: 18.43, Call Option Price: 0.75, Delta: 0.29, Gamma: 2.96, Theta: 1.27, Vega: 3.59, Rho: 1.89
#   Strike Price: 18.95, Call Option Price: 0.69, Delta: 0.23, Gamma: 2.19, Theta: 1.07, Vega: 2.99, Rho: 1.79
#   Strike Price: 19.48, Call Option Price: 0.64, Delta: 0.23, Gamma: 2.19, Theta: 1.08, Vega: 3.04, Rho: 1.69
#   Strike Price: 20.01, Call Option Price: 0.59, Delta: 0.23, Gamma: 2.19, Theta: 1.09, Vega: 3.09, Rho: 1.60
#   Strike Price: 20.53, Call Option Price: 0.55, Delta: 0.23, Gamma: 2.19, Theta: 1.11, Vega: 3.15, Rho: 1.50
