# %% [markdown]
# ## Load libraries

# %%
# Imports
import numpy as np
from numpy import genfromtxt
import matplotlib 
from matplotlib import pyplot as plt
import pandas as pd
import os
# %matplotlib inline
import multiprocessing

import sklearn
import dcor

import tigramite
from tigramite import data_processing as pp
from tigramite.toymodels import structural_causal_processes as toys
from tigramite import plotting as tp
from tigramite.pcmci import PCMCI
from tigramite.lpcmci import LPCMCI
import tigramite.independence_tests 

from tigramite.toymodels import structural_causal_processes as toys

# %% [markdown]
# ## Data processing

# %%
df = pd.read_parquet("amalgamated.parquet")

# %%
df.columns
# Out:
# Index(['AdrActCnt', 'AdrBal1in100KCnt', 'AdrBal1in100MCnt', 'AdrBal1in10BCnt',
#        'AdrBal1in10KCnt', 'AdrBal1in10MCnt', 'AdrBal1in1BCnt',
#        'AdrBal1in1KCnt', 'AdrBal1in1MCnt', 'AdrBalCnt',
#        ...
#        'EWL', 'ERUS', 'EWZ', 'EWY', 'ENZL', 'EWD', 'EWM',
#        'Global_Liquidity_Index', 'Normalized_GLI', 'Normalized_SPY'],
#       dtype='object', length=166)

# %%
#df = df.drop(columns=['time']).reset_index(drop=True)

# %%
df.shape
# Out:
# (1438, 166)

# %%
df = df.tail(520)

# %%
df = df.reset_index(drop=True)

# %%
metrics = [
    "ReferenceRateUSD",
    "AdrBalNtv0.01Cnt",
    "AdrBalNtv0.1Cnt",
    "AdrBalNtv1Cnt",
    "BlkSizeMeanByte",
    "FeeByteMeanNtv",
    "FlowInExNtv",
    "FlowOutExNtv",
    "HashRate",
    "SplyAct1d",
    "TxCnt",
    "^IRX",
    "^TNX",
    "^TYX",
    "SPY",
    "QQQ",
    "Global_Liquidity_Index"
]

# %%
df = df[metrics]
df
# Out:
#      ReferenceRateUSD  AdrBalNtv0.01Cnt  AdrBalNtv0.1Cnt  AdrBalNtv1Cnt  \
# 0        62373.885621           9139450          3245357         811625
# 1        60865.447052           9141570          3244036         809011
# 2        63031.672902           9143940          3242600         806994
# 3        60393.980274           9147841          3243043         807146
# 4        58563.335990           9151206          3244074         807420
# ..                ...               ...              ...            ...
# 515      43605.155555          12724066          4583262        1023340
# 516      43870.238234          12719547          4580759        1023231
# 517      42491.122908          12733838          4580040        1023628
# 518      43436.959427          12743326          4581886        1023743
# 519      42670.679718          12753405          4584403        1024058
#
#      BlkSizeMeanByte  FeeByteMeanNtv   FlowInExNtv  FlowOutExNtv  \
# 0       1.144247e+06    8.769500e-08  30343.055196  23819.745636
# 1       1.112111e+06    6.967900e-08  15663.127389  35089.685077
# 2       1.219891e+06    7.515300e-08  16941.822580  23947.233902
# 3       1.090372e+06    7.155900e-08  22701.109195  23099.529453
# 4       1.251451e+06    6.816600e-08  35624.404543  23147.724894
# ..               ...             ...           ...           ...
# 515     1.708325e+06    1.627281e-06  20075.140452  20332.299706
# 516     1.700745e+06    1.109639e-06  25767.774305  21488.599482
# 517     1.670873e+06    1.275813e-06  15074.672745  31705.858513
# 518     1.695263e+06    1.114453e-06  15879.873592  18531.696665
# 519     1.680204e+06    8.391340e-07  16511.878936  22081.782606
#
#          HashRate      SplyAct1d   TxCnt   ^IRX   ^TNX   ^TYX         SPY  \
# 0    1.577321e+08  475158.767625  281476  0.050  1.655  2.091  453.119995
# 1    1.816914e+08  464062.257587  286798  0.050  1.635  2.085  455.549988
# 2    1.497457e+08  437036.850081  295695  0.050  1.619  2.051  455.959991
# 3    1.567338e+08  413406.751805  286086  0.050  1.529  1.942  453.940002
# 4    1.527406e+08  370589.037579  297884  0.048  1.568  1.963  458.320007
# ..            ...            ...     ...    ...    ...    ...         ...
# 515  4.884860e+08  298825.317741  589222  5.210  3.894  4.036  472.700012
# 516  5.620935e+08  280265.014624  623750  5.208  3.901  4.054  473.649994
# 517  4.617484e+08  343694.296619  541778  5.235  3.789  3.945  476.510010
# 518  4.331128e+08  303730.031379  417387  5.218  3.850  3.988  476.690002
# 519  5.404962e+08  321706.343430  579710  5.180  3.866  4.019  475.309998
#
#             QQQ  Global_Liquidity_Index
# 0    374.100006              933.780292
# 1    377.929993              940.034018
# 2    379.119995              942.110898
# 3    380.000000              941.845493
# 4    384.220001              950.290018
# ..          ...                     ...
# 515  407.769989              973.185377
# 516  408.380005              974.601569
# 517  411.500000              981.543728
# 518  411.299988              981.290662
# 519  409.519989              977.718755
#
# [520 rows x 17 columns]

# %%
array = df.to_numpy()

# %%
from tigramite.independence_tests.parcorr_mult import ParCorrMult
from tigramite.independence_tests.cmiknn import CMIknn
from tigramite.independence_tests.robust_parcorr import RobustParCorr

var_names = metrics

pc = ParCorrMult()
cmi = CMIknn()
robustpc = RobustParCorr()

df_final = pp.DataFrame(array, var_names=var_names)

# %% [markdown]
# ## PCMCI+

# %%
# %%time

pcmci = PCMCI(dataframe=df_final, 
                       cond_ind_test=robustpc,
                       verbosity=0)

# Define the analysis parameters
tau_max = 5
pc_alpha = 0.01
# Add or adjust other parameters as needed for PCMCI+

# Run PCMCI+
result = pcmci.run_pcmciplus(
    tau_max=tau_max,
    pc_alpha=pc_alpha
    # Include additional parameters or adjust as per PCMCI+ requirements
)
# Out:
# CPU times: user 6.98 s, sys: 0 ns, total: 6.98 s
# Wall time: 6.98 s

# %% [markdown]
# ## LPCMCI

# %% [raw]
# %%time
#
# lpcmci_aug = LPCMCI(dataframe=df_final,
#                 cond_ind_test=robustpc,
#                 verbosity=0)
#
# # Define the analysis parameters
# tau_max = 5
# pc_alpha = 0.01
# #max_cond_px = 2  # Example value, adjust based on your data
# #max_p_global = 2 # Use the default unless computational time is a concern
# #max_p_non_ancestral = 2 # Same as above
# #max_q_global = 5  # Same as above
# #max_pds_set = 5  # Same as above
# #n_preliminary_iterations = 2  # Adjust as needed
#
# # Run LPCMCI
# result = lpcmci_aug.run_lpcmci(
#     tau_max=tau_max,
#     pc_alpha=pc_alpha
# #    max_cond_px=max_cond_px,
# #    max_p_global=max_p_global,
# #    max_p_non_ancestral=max_p_non_ancestral,
# #    max_q_global=max_q_global,
# #    max_pds_set=max_pds_set,
# #    n_preliminary_iterations=n_preliminary_iterations
# )

# %% [markdown]
# ## Plotting

# %%
# %%time

tp.plot_graph(
    figsize=(40, 40),
    val_matrix=result['val_matrix'],
    graph=result['graph'],
    var_names=var_names,
    link_colorbar_label='MCI',
    node_size=0.2,
    node_label_size = 20,
    link_label_fontsize = 50,
    curved_radius = 0.25
)

# Save the plot to an SVG file before showing it
plt.savefig('lpcmci_graph.jpg', format='jpg')

plt.show()
# Out:
# CPU times: user 2.51 s, sys: 651 ms, total: 3.16 s
# Wall time: 2.34 s

# %%
# Initialize a list to store the relation information
relation_info = []

# Iterate over the rows, columns, and tau of the graph matrix
for i, x_var in enumerate(var_names):
    for j, y_var in enumerate(var_names):
        for tau in range(result['graph'].shape[2]):
            relation = result['graph'][i, j, tau]

            # Check if the relation is not an empty string
            if relation:
                mci_val = result['val_matrix'][i, j]
                p_val = result['p_matrix'][i, j]

                # Check if mci_val and p_val are arrays and extract the first element
                if isinstance(mci_val, np.ndarray) and mci_val.size > 0:
                    mci_val = mci_val[0]
                if isinstance(p_val, np.ndarray) and p_val.size > 0:
                    p_val = p_val[0]

                # Append the relation information to the list only if abs(MCI) >= 0.001 and p-value < pc_alpha
                if mci_val is not None and p_val is not None and abs(mci_val) >= 0.001 and p_val < pc_alpha:
                    relation_info.append((x_var, y_var, tau, relation, mci_val, p_val))

# Sort the list by MCI value in descending order
relation_info.sort(key=lambda x: x[4], reverse=True)

# Print the sorted information
for x_var, y_var, tau, relation, mci_val, p_val in relation_info:
    print(f"Relation between '{x_var}' and '{y_var}' at lag {tau}:")
    print(f"  Type: {relation}")
    print(f"  MCI Value: {mci_val:.4f}")  # Adjust the number of decimal places as needed
    print(f"  P-Value: {p_val:.4g}")  # Adjust the number of decimal places as needed
    print("-" * 40)  # Separator for readability
# Out:
# Relation between '^TNX' and '^TYX' at lag 0:
#   Type: <--
#   MCI Value: 0.9052
#   P-Value: 4.881e-189
# ----------------------------------------
# Relation between '^TYX' and '^TNX' at lag 0:
#   Type: -->
#   MCI Value: 0.9052
#   P-Value: 4.881e-189
# ----------------------------------------
# Relation between 'SPY' and 'Global_Liquidity_Index' at lag 0:
#   Type: <--
#   MCI Value: 0.7456
#   P-Value: 6.657e-91
# ----------------------------------------
# Relation between 'Global_Liquidity_Index' and 'SPY' at lag 0:
#   Type: -->
#   MCI Value: 0.7456
#   P-Value: 6.657e-91
# ----------------------------------------
# Relation between 'Global_Liquidity_Index' and 'SPY' at lag 3:
#   Type: -->
#   MCI Value: 0.7456
#   P-Value: 6.657e-91
# ----------------------------------------
# Relation between 'QQQ' and 'Global_Liquidity_Index' at lag 0:
#   Type: x-x
#   MCI Value: 0.6677
#   P-Value: 1.347e-66
# ----------------------------------------
# Relation between 'Global_Liquidity_Index' and 'QQQ' at lag 0:
#   Type: x-x
#   MCI Value: 0.6677
#   P-Value: 1.347e-66
# ----------------------------------------
# Relation between 'FlowInExNtv' and 'FlowOutExNtv' at lag 0:
#   Type: -->
#   MCI Value: 0.6108
#   P-Value: 5.812e-53
# ----------------------------------------
# Relation between 'FlowOutExNtv' and 'FlowInExNtv' at lag 0:
#   Type: <--
#   MCI Value: 0.6108
#   P-Value: 5.812e-53
# ----------------------------------------
# Relation between 'AdrBalNtv0.01Cnt' and 'AdrBalNtv0.1Cnt' at lag 0:
#   Type: x-x
#   MCI Value: 0.4859
#   P-Value: 4.154e-31
# ----------------------------------------
# Relation between 'AdrBalNtv0.01Cnt' and 'AdrBalNtv0.1Cnt' at lag 1:
#   Type: -->
#   MCI Value: 0.4859
#   P-Value: 4.154e-31
# ----------------------------------------
# Relation between 'AdrBalNtv0.1Cnt' and 'AdrBalNtv0.01Cnt' at lag 0:
#   Type: x-x
#   MCI Value: 0.4859
#   P-Value: 4.154e-31
# ----------------------------------------
# Relation between 'HashRate' and 'TxCnt' at lag 0:
#   Type: x-x
#   MCI Value: 0.4653
#   P-Value: 2.745e-28
# ----------------------------------------
# Relation between 'TxCnt' and 'HashRate' at lag 0:
#   Type: x-x
#   MCI Value: 0.4653
#   P-Value: 2.745e-28
# ----------------------------------------
# Relation between 'AdrBalNtv0.1Cnt' and 'AdrBalNtv1Cnt' at lag 0:
#   Type: x-x
#   MCI Value: 0.3457
#   P-Value: 1.652e-15
# ----------------------------------------
# Relation between 'AdrBalNtv1Cnt' and 'AdrBalNtv0.1Cnt' at lag 0:
#   Type: x-x
#   MCI Value: 0.3457
#   P-Value: 1.652e-15
# ----------------------------------------
# Relation between 'SPY' and 'QQQ' at lag 0:
#   Type: x-x
#   MCI Value: 0.3077
#   P-Value: 1.565e-12
# ----------------------------------------
# Relation between 'QQQ' and 'SPY' at lag 0:
#   Type: x-x
#   MCI Value: 0.3077
#   P-Value: 1.565e-12
# ----------------------------------------
# Relation between 'AdrBalNtv0.01Cnt' and 'AdrBalNtv1Cnt' at lag 0:
#   Type: x-x
#   MCI Value: 0.3055
#   P-Value: 2.647e-12
# ----------------------------------------
# Relation between 'AdrBalNtv0.01Cnt' and 'AdrBalNtv1Cnt' at lag 4:
#   Type: -->
#   MCI Value: 0.3055
#   P-Value: 2.647e-12
# ----------------------------------------
# Relation between 'AdrBalNtv0.01Cnt' and 'AdrBalNtv1Cnt' at lag 5:
#   Type: -->
#   MCI Value: 0.3055
#   P-Value: 2.647e-12
# ----------------------------------------
# Relation between 'AdrBalNtv1Cnt' and 'AdrBalNtv0.01Cnt' at lag 0:
#   Type: x-x
#   MCI Value: 0.3055
#   P-Value: 2.647e-12
# ----------------------------------------
# Relation between 'FeeByteMeanNtv' and 'SplyAct1d' at lag 0:
#   Type: <--
#   MCI Value: 0.2612
#   P-Value: 2.925e-09
# ----------------------------------------
# Relation between 'SplyAct1d' and 'FeeByteMeanNtv' at lag 0:
#   Type: -->
#   MCI Value: 0.2612
#   P-Value: 2.925e-09
# ----------------------------------------
# Relation between 'FlowOutExNtv' and 'SplyAct1d' at lag 0:
#   Type: o-o
#   MCI Value: 0.1748
#   P-Value: 8.247e-05
# ----------------------------------------
# Relation between 'SplyAct1d' and 'FlowOutExNtv' at lag 0:
#   Type: o-o
#   MCI Value: 0.1748
#   P-Value: 8.247e-05
# ----------------------------------------
# Relation between '^IRX' and '^TNX' at lag 0:
#   Type: o-o
#   MCI Value: 0.1536
#   P-Value: 0.0005521
# ----------------------------------------
# Relation between '^TNX' and '^IRX' at lag 0:
#   Type: o-o
#   MCI Value: 0.1536
#   P-Value: 0.0005521
# ----------------------------------------
# Relation between 'ReferenceRateUSD' and 'TxCnt' at lag 0:
#   Type: <--
#   MCI Value: 0.1449
#   P-Value: 0.00113
# ----------------------------------------
# Relation between 'TxCnt' and 'ReferenceRateUSD' at lag 0:
#   Type: -->
#   MCI Value: 0.1449
#   P-Value: 0.00113
# ----------------------------------------
# Relation between 'FlowInExNtv' and 'SplyAct1d' at lag 0:
#   Type: -->
#   MCI Value: 0.1416
#   P-Value: 0.00149
# ----------------------------------------
# Relation between 'SplyAct1d' and 'FlowInExNtv' at lag 0:
#   Type: <--
#   MCI Value: 0.1416
#   P-Value: 0.00149
# ----------------------------------------
# Relation between 'AdrBalNtv1Cnt' and '^IRX' at lag 0:
#   Type: <--
#   MCI Value: 0.1265
#   P-Value: 0.004557
# ----------------------------------------
# Relation between '^IRX' and 'AdrBalNtv1Cnt' at lag 0:
#   Type: -->
#   MCI Value: 0.1265
#   P-Value: 0.004557
# ----------------------------------------
# Relation between 'FlowInExNtv' and 'TxCnt' at lag 0:
#   Type: o-o
#   MCI Value: 0.1173
#   P-Value: 0.008641
# ----------------------------------------
# Relation between 'TxCnt' and 'FlowInExNtv' at lag 0:
#   Type: o-o
#   MCI Value: 0.1173
#   P-Value: 0.008641
# ----------------------------------------
# Relation between 'BlkSizeMeanByte' and 'TxCnt' at lag 0:
#   Type: o-o
#   MCI Value: 0.1162
#   P-Value: 0.009407
# ----------------------------------------
# Relation between 'TxCnt' and 'BlkSizeMeanByte' at lag 0:
#   Type: o-o
#   MCI Value: 0.1162
#   P-Value: 0.009407
# ----------------------------------------
# Relation between 'BlkSizeMeanByte' and 'HashRate' at lag 0:
#   Type: x-x
#   MCI Value: -0.2121
#   P-Value: 1.661e-06
# ----------------------------------------
# Relation between 'HashRate' and 'BlkSizeMeanByte' at lag 0:
#   Type: x-x
#   MCI Value: -0.2121
#   P-Value: 1.661e-06
# ----------------------------------------
# Relation between 'FeeByteMeanNtv' and 'HashRate' at lag 0:
#   Type: x-x
#   MCI Value: -0.3202
#   P-Value: 1.875e-13
# ----------------------------------------
# Relation between 'HashRate' and 'FeeByteMeanNtv' at lag 0:
#   Type: x-x
#   MCI Value: -0.3202
#   P-Value: 1.875e-13
# ----------------------------------------

# %%
# Initialize a list to store the auto-relation information
auto_relation_info = []

# Define tau_max
tau_max = result['graph'].shape[2]

# Iterate over the variables
for i, var in enumerate(var_names):
    total_mci_val = 0
    total_p_val = 0
    count = 0

    # Accumulate the MCI values and p-values from 0 to tau_max
    for tau in range(tau_max):
        if result['graph'][i, i, tau]:
            mci_val = result['val_matrix'][i, i, tau]
            p_val = result['p_matrix'][i, i, tau]

            # Extract the first element if they are arrays
            if isinstance(mci_val, np.ndarray) and mci_val.size > 0:
                mci_val = mci_val[0]
            if isinstance(p_val, np.ndarray) and p_val.size > 0:
                p_val = p_val[0]

            # Accumulate values
            if mci_val is not None and p_val is not None:
                total_mci_val += mci_val
                total_p_val += p_val
                count += 1

    # Calculate averages if count is non-zero
    if count > 0:
        avg_mci_val = total_mci_val / count
        avg_p_val = total_p_val / count
        auto_relation_info.append((var, avg_mci_val, avg_p_val))

# Sort the list by average MCI value in descending order
auto_relation_info.sort(key=lambda x: x[1], reverse=True)

# Print the sorted information
for var, avg_mci_val, avg_p_val in auto_relation_info:
    print(f"Average Auto-MCI of '{var}':")
    print(f"  Average MCI Value: {avg_mci_val:.4f}")  # Adjust the number of decimal places as needed
    print(f"  Average P-Value: {avg_p_val:.4g}")  # Adjust the number of decimal places as needed
    print("-" * 40)  # Separator for readability
# Out:
# Average Auto-MCI of 'AdrBalNtv1Cnt':
#   Average MCI Value: 0.6620
#   Average P-Value: 9.957e-65
# ----------------------------------------
# Average Auto-MCI of 'FeeByteMeanNtv':
#   Average MCI Value: 0.5397
#   Average P-Value: 1.623e-39
# ----------------------------------------
# Average Auto-MCI of 'SPY':
#   Average MCI Value: 0.3654
#   Average P-Value: 2.146e-17
# ----------------------------------------
# Average Auto-MCI of '^TYX':
#   Average MCI Value: 0.3638
#   Average P-Value: 2.791e-17
# ----------------------------------------
# Average Auto-MCI of '^TNX':
#   Average MCI Value: 0.3596
#   Average P-Value: 7.256e-17
# ----------------------------------------
# Average Auto-MCI of 'ReferenceRateUSD':
#   Average MCI Value: 0.3550
#   Average P-Value: 0.002928
# ----------------------------------------
# Average Auto-MCI of 'QQQ':
#   Average MCI Value: 0.3283
#   Average P-Value: 3.078e-06
# ----------------------------------------
# Average Auto-MCI of 'Global_Liquidity_Index':
#   Average MCI Value: 0.3092
#   Average P-Value: 1.085e-12
# ----------------------------------------
# Average Auto-MCI of '^IRX':
#   Average MCI Value: 0.3039
#   Average P-Value: 2.703e-05
# ----------------------------------------
# Average Auto-MCI of 'AdrBalNtv0.1Cnt':
#   Average MCI Value: 0.2826
#   Average P-Value: 8.546e-06
# ----------------------------------------
# Average Auto-MCI of 'AdrBalNtv0.01Cnt':
#   Average MCI Value: 0.2490
#   Average P-Value: 0.002435
# ----------------------------------------
# Average Auto-MCI of 'BlkSizeMeanByte':
#   Average MCI Value: 0.2368
#   Average P-Value: 0.00244
# ----------------------------------------
# Average Auto-MCI of 'SplyAct1d':
#   Average MCI Value: 0.2088
#   Average P-Value: 0.002492
# ----------------------------------------
# Average Auto-MCI of 'TxCnt':
#   Average MCI Value: 0.1834
#   Average P-Value: 0.002624
# ----------------------------------------
# Average Auto-MCI of 'HashRate':
#   Average MCI Value: 0.1626
#   Average P-Value: 0.0008498
# ----------------------------------------
# Average Auto-MCI of 'FlowInExNtv':
#   Average MCI Value: 0.1578
#   Average P-Value: 0.000388
# ----------------------------------------
